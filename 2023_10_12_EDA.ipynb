# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import platform
import matplotlib as mpl
from matplotlib import rc

plt.rcParams["axes.unicode_minus"] = False
rc("font", family="AppleGothic")
get_ipython().run_line_magic("matplotlib", "inline")

# %%
data = pd.read_excel("reviews_concat.xlsx", index_col=0)
data
# Out:
#       platform   store      date                               review  rating  \
# 0       mustit  google  20230914                                    굿       5
# 1       balaan  google  20230914  자주 이용하지는 않지만 기분전환으로 조그만거 하나씩 사고 있어요       5
# 2       balaan  google  20230914                   가격이 싸니까 직접 포장해서 줘요       5
# 3       balaan  google  20230914                  포장이 안돼서 오는게 좀 그렇지만        5
# 4       balaan  google  20230914     앱깔고 눈팅만 하다가 전부터 사고싶던게 특가로 떠서 샀어요       5
# ...        ...     ...       ...                                  ...     ...
# 13361   mustit  google  20141028                                  좋아요       5
# 13362   mustit  google  20140805                               너무 좋아요       5
# 13363   mustit  google  20140703                                 좋습니다       5
# 13364   mustit  google  20140530                                  좋아요       5
# 13365   mustit  google  20140522                                 좋습니다       5
#
#       category  label
# 0       만족도&기타      1
# 1       만족도&기타      1
# 2      가격&프로모션      1
# 3        상품 품질      0
# 4      가격&프로모션      1
# ...        ...    ...
# 13361   만족도&기타      1
# 13362   만족도&기타      1
# 13363   만족도&기타      1
# 13364   만족도&기타      1
# 13365   만족도&기타      1
#
# [13366 rows x 7 columns]

# %%
# 트렌비
data_ne = data[data["label"]== 0 ]
data_ne
# Out:
#       platform   store      date                    review  rating   category  \
# 3       balaan  google  20230914       포장이 안돼서 오는게 좀 그렇지만        5      상품 품질
# 22      trenbe   apple  20230913                  렉이 넘 심해요       3       앱 오류
# 23      trenbe   apple  20230913  다시 처음부터 봐야하는데 이게 너무 불편해요       3  UX/UI 편의성
# 24      trenbe   apple  20230913    상품 하나 구경하고 뒤로가기하면 렉걸려서       3       앱 오류
# 30      balaan  google  20230912         배송이 좀 늦어져서 짜증낫었는데       5         배송
# ...        ...     ...       ...                       ...     ...        ...
# 12811   balaan  google  20210426                     최악이네요       1     만족도&기타
# 12836   trenbe  google  20210321                     최악이네요       1     만족도&기타
# 12869   trenbe  google  20210216                 배송이 넘 느려요       1         배송
# 12894   balaan  google  20210103                     최악입니다       1     만족도&기타
# 12982   trenbe  google  20200819                       쓰레기       1     만족도&기타
#
#        label
# 3          0
# 22         0
# 23         0
# 24         0
# 30         0
# ...      ...
# 12811      0
# 12836      0
# 12869      0
# 12894      0
# 12982      0
#
# [2484 rows x 7 columns]

# %% [markdown]
# # 트렌비
# - 트렌비의 부정 비율을 보면 2021.08~2022.01 이 기간동안 전체 리뷰 개수와 상관없이 부정 리뷰 개수는 비슷함.
# - ?? 긍정적인 리뷰도 많아졌지만 부정 리뷰 개수가 비슷한 것으로 보아 개선하지 않았나? 의문
# - 특히 2021년 8월 전에는 부정 리뷰가 50개를 넘지 않았는데 2021.08에 처음으로 100개를 돌파.
# - 이 기간의 부정 리뷰 카테고리 비율을 보고 탑 3를 태블로로 확인함.
# - 앱 오류가 지나치게 높은 달 2021.08/2021.10 앱 오류는 앱 관련 리뷰일테고 (워클로 키워드보면서 확실하게 봐야 함.)
# - 만족도기타와 고객센터 부분은 워클 키워드를 보며 어떤 부분이 불만족스러운지 확인 필요
# - 앱 오류가 탑 3에 포함된 달을 보면 만족도 기타와 고객센터는 계속 비슷한 개수 유지.(아마도 개선하지 않았다?)
# - 2021.12~2022.01 고객센터와 가격이 함께 탑 3이다? 이벤트 과정에서 무슨 일이 있는 듯 (워클로 키워드 확인)
#     - 워클 키워드 확인 (앱오류 2021.08/2021.10   만족도,고객 2021.08_2021.11   고객,가격 2021.12~2022.01)

# %%
# 트렌비
trenbe = data_ne[data_ne["platform"]=='trenbe']
trenbe
# Out:
#       platform   store      date  \
# 22      trenbe   apple  20230913
# 23      trenbe   apple  20230913
# 24      trenbe   apple  20230913
# 42      trenbe  google  20230912
# 71      trenbe  google  20230911
# ...        ...     ...       ...
# 12799   trenbe   apple  20210516
# 12809   trenbe  google  20210429
# 12836   trenbe  google  20210321
# 12869   trenbe  google  20210216
# 12982   trenbe  google  20200819
#
#                                                   review  rating   category  \
# 22                                              렉이 넘 심해요       3       앱 오류
# 23                              다시 처음부터 봐야하는데 이게 너무 불편해요       3  UX/UI 편의성
# 24                                상품 하나 구경하고 뒤로가기하면 렉걸려서       3       앱 오류
# 42                   욕이 아까울정도로 무책임 무성의 무대응 고객을 아주 으로 아는곳       1       고객센터
# 71     요새들어 로딩이 느려지고 렉도 잘걸려서 화면이 정지가 되어있구 앱사용시 핸드폰에 발...       1       앱 오류
# ...                                                  ...     ...        ...
# 12799                                              너무느려요       1       앱 오류
# 12809                                             너무 느려요       3       앱 오류
# 12836                                              최악이네요       1     만족도&기타
# 12869                                          배송이 넘 느려요       1         배송
# 12982                                                쓰레기       1     만족도&기타
#
#        label
# 22         0
# 23         0
# 24         0
# 42         0
# 71         0
# ...      ...
# 12799      0
# 12809      0
# 12836      0
# 12869      0
# 12982      0
#
# [1428 rows x 7 columns]

# %%
trenbe['date']=trenbe['date'].astype(str)
# Out:
# /var/folders/58/gn_xg82n3_d5871yqsk64tm40000gn/T/ipykernel_5080/3754854654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trenbe['date']=trenbe['date'].astype(str)

# %% [markdown]
# ### 트렌비 2021.08
# - 앱 오류가 지나치가 많음

# %%
trenbe_2021_08 = trenbe[trenbe['date'].str.contains('202108')]
trenbe_2021_08
# Out:
#       platform   store      date  \
# 6241    trenbe  google  20210831
# 6245    trenbe  google  20210830
# 6246    trenbe  google  20210830
# 6247    trenbe  google  20210830
# 6248    trenbe  google  20210830
# ...        ...     ...       ...
# 12521   trenbe   apple  20210807
# 12522   trenbe   apple  20210807
# 12617   trenbe   apple  20210802
# 12618   trenbe   apple  20210802
# 12619   trenbe   apple  20210802
#
#                                                   review  rating category  \
# 6241             업데이트하고 나서 정말 느려졌어요. 그전 버전이 훨 빠르고 좋아요.ㅠㅠ       2     앱 오류
# 6245                          아 쇼핑 하는데 너무 답답해요 계속 화면 멈추고       2     앱 오류
# 6246                                앱이자꾸멈추고안되는데 물건을어째사죠?       1     앱 오류
# 6247                                               렉 심해요       2     앱 오류
# 6248                                       렉이 진짜 심하네요 ㅠㅠ       1     앱 오류
# ...                                                  ...     ...      ...
# 12521                                     \n\n안내도 전혀 없어요       1   만족도&기타
# 12522      미안하다는것도 전혀 없고 \n돈만 안뜯겼을 뿐 돈까지 뜯겼으면 사기당할 뻔 했네요       1  가격&프로모션
# 12617  벨트를 주문했는데 분명 남성악세서리 벨트 이렇게 되있는데 오늘 벨트를 받고 나니까 ...       1   만족도&기타
# 12618                                반품교환 안되는 물품이라고만 되있고       1       배송
# 12619                                전화를 몇번이나 드려도 안받으시네요       1     고객센터
#
#        label
# 6241       0
# 6245       0
# 6246       0
# 6247       0
# 6248       0
# ...      ...
# 12521      0
# 12522      0
# 12617      0
# 12618      0
# 12619      0
#
# [118 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import re

# %%
trenbe_2021_08['review'] = trenbe_2021_08['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))
# Out:
# /var/folders/58/gn_xg82n3_d5871yqsk64tm40000gn/T/ipykernel_5080/1841266817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trenbe_2021_08['review'] = trenbe_2021_08['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
import jpype
from konlpy.tag import Okt
okt = Okt()

trenbe_2021_08_nouns = []
for cmt in trenbe_2021_08['review']:
    trenbe_2021_08_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
trenbe_2021_08_nouns2 = []
word = [w for w in trenbe_2021_08_nouns if len(w) > 1]  
trenbe_2021_08_nouns2.extend(word)

# %%
trenbe_2021_08_nouns2
# Out:
# ['업데이트',
#  '정말',
#  '버전',
#  '쇼핑',
#  '계속',
#  '화면',
#  '자꾸',
#  '물건',
#  '심해',
#  '진짜',
#  '사진',
#  '화면',
#  '계속',
#  '로딩',
#  '버튼',
#  '수가',
#  '오늘',
#  '업데이트',
#  '상품',
#  '보기',
#  '먹통',
#  '버튼',
#  '노트',
#  '상품',
#  '수가',
#  '홈페이지',
#  '자주',
#  '마찬가지',
#  '구매',
#  '처음',
#  '겨우',
#  '사진',
#  '하나',
#  '간장',
#  '트래비',
#  '자꾸',
#  '화면',
#  '현상',
#  '계속',
#  '계속',
#  '사용',
#  '가방',
#  '가격',
#  '합리',
#  '신뢰',
#  '진짜',
#  '이번',
#  '업데이트',
#  '속도',
#  '별하나',
#  '장바구니',
#  '그냥',
#  '허위',
#  '물건',
#  '사고',
#  '요즘',
#  '클릭',
#  '다시',
#  '시작',
#  '아주',
#  '어플',
#  '어제',
#  '오늘',
#  '자꾸',
#  '다른',
#  '업뎃후',
#  '화면',
#  '자꾸',
#  '이미지',
#  '안보',
#  '스크롤바',
#  '리뷰',
#  '퍼센트',
#  '조치',
#  '사이트',
#  '계속',
#  '뭔가',
#  '업데이트',
#  '인내심',
#  '테스트',
#  '거참',
#  '쓰레기',
#  '짜증',
#  '자꾸',
#  '요즘',
#  '진짜',
#  '로딩',
#  '무오',
#  '로딩',
#  '시간',
#  '쇼핑',
#  '어플',
#  '계속',
#  '어플',
#  '계속',
#  '짜증',
#  '구매',
#  '버튼',
#  '안눌리',
#  '상품',
#  '금액',
#  '자꾸',
#  '로딩',
#  '손좀',
#  '구매',
#  '화면',
#  '업데이트',
#  '가기',
#  '어플',
#  '사진',
#  '아이폰',
#  '다른',
#  '수정',
#  '뭘좀',
#  '상세',
#  '페이',
#  '도안',
#  '그냥',
#  '자꾸',
#  '사려',
#  '고해',
#  '자꾸',
#  '크롬',
#  '인터넷',
#  '자꾸',
#  '원래',
#  '오늘',
#  '기능',
#  '계속',
#  '업뎃',
#  '누가',
#  '업데이트',
#  '잘못',
#  '다운',
#  '하얀색',
#  '화면',
#  '다음',
#  '네이버',
#  '사이트',
#  '기분',
#  '아이폰',
#  '정도',
#  '화면',
#  '최악',
#  '최악',
#  '제품',
#  '문의',
#  '판매',
#  '누락',
#  '취소',
#  '정도',
#  '사안',
#  '문의',
#  '연락',
#  '처리',
#  '데이터',
#  '장바구니',
#  '기록',
#  '다시',
#  '로그인',
#  '설정',
#  '경우',
#  '사전',
#  '고지',
#  '안내',
#  '품절',
#  '주문',
#  '상품',
#  '가지',
#  '그냥',
#  '취소',
#  '품절',
#  '주문',
#  '그것',
#  '구매',
#  '가지',
#  '상품',
#  '거지',
#  '확률',
#  '구매',
#  '품목',
#  '환불',
#  '안내',
#  '전혀',
#  '전혀',
#  '사기',
#  '벨트',
#  '주문',
#  '분명',
#  '남성',
#  '벨트',
#  '오늘',
#  '벨트',
#  '여자',
#  '사이즈',
#  '제대로',
#  '표기',
#  '반품',
#  '교환',
#  '물품',
#  '전화',
#  '몇번',
#  '업데이트',
#  '정말',
#  '버전',
#  '쇼핑',
#  '계속',
#  '화면',
#  '자꾸',
#  '물건',
#  '심해',
#  '진짜',
#  '사진',
#  '화면',
#  '계속',
#  '로딩',
#  '버튼',
#  '수가',
#  '오늘',
#  '업데이트',
#  '상품',
#  '보기',
#  '먹통',
#  '버튼',
#  '노트',
#  '상품',
#  '수가',
#  '홈페이지',
#  '자주',
#  '마찬가지',
#  '구매',
#  '처음',
#  '겨우',
#  '사진',
#  '하나',
#  '간장',
#  '트래비',
#  '자꾸',
#  '화면',
#  '현상',
#  '계속',
#  '계속',
#  '사용',
#  '진짜',
#  '이번',
#  '업데이트',
#  '속도',
#  '별하나',
#  '장바구니',
#  '그냥',
#  '허위',
#  '물건',
#  '사고',
#  '요즘',
#  '클릭',
#  '다시',
#  '시작',
#  '아주',
#  '어플',
#  '이번',
#  '업데이트',
#  '현상',
#  '자주',
#  '발생',
#  '어플',
#  '계속',
#  '다른',
#  '러신',
#  '조취를',
#  '어제',
#  '오늘',
#  '자꾸',
#  '다른',
#  '업뎃후',
#  '화면',
#  '자꾸',
#  '이미지',
#  '안보',
#  '스크롤바',
#  '리뷰',
#  '퍼센트',
#  '조치',
#  '사이트',
#  '계속',
#  '뭔가',
#  '업데이트',
#  '인내심',
#  '테스트',
#  '거참',
#  '쓰레기',
#  '짜증',
#  '자꾸',
#  '요즘',
#  '진짜',
#  '로딩',
#  '무오',
#  '로딩',
#  '시간',
#  '튕겨',
#  '쇼핑',
#  '어플',
#  '계속',
#  '어플',
#  '계속',
#  '짜증',
#  '구매',
#  '버튼',
#  '안눌리',
#  '상품',
#  '금액',
#  '자꾸',
#  '로딩',
#  '손좀',
#  '구매',
#  '화면',
#  '업데이트',
#  '가기',
#  '어플',
#  '사진',
#  '아이폰',
#  '다른',
#  '수정',
#  '뭘좀',
#  '상세',
#  '페이',
#  '도안',
#  '그냥',
#  '자꾸',
#  '사려',
#  '고해',
#  '자꾸',
#  '크롬',
#  '인터넷',
#  '자꾸',
#  '원래',
#  '오늘',
#  '기능',
#  '계속',
#  '업뎃',
#  '누가',
#  '업데이트',
#  '잘못',
#  '프로모션',
#  '다운',
#  '하얀색',
#  '화면',
#  '다음',
#  '네이버',
#  '사이트',
#  '아이폰',
#  '정도',
#  '화면',
#  '요하',
#  '최악',
#  '최악',
#  '제품',
#  '문의',
#  '판매',
#  '누락',
#  '취소',
#  '정도',
#  '사안',
#  '문의',
#  '연락',
#  '처리',
#  '데이터',
#  '장바구니',
#  '기록',
#  '다시',
#  '로그인',
#  '설정',
#  '경우',
#  '사전',
#  '고지',
#  '해외',
#  '구매',
#  '일일',
#  '가격',
#  '비교',
#  '구매',
#  '시간',
#  '안내',
#  '품절',
#  '주문',
#  '상품',
#  '가지',
#  '그냥',
#  '취소',
#  '안내',
#  '전혀',
#  '전혀',
#  '사기',
#  '벨트',
#  '주문',
#  '분명',
#  '남성',
#  '벨트',
#  '오늘',
#  '벨트',
#  '여자',
#  '반품',
#  '교환',
#  '물품',
#  '전화',
#  '몇번']

# %%
from collections import Counter

# Counter 객체 생성
trenbe_2021_08_count = Counter(trenbe_2021_08_nouns2)

# %%
max = 50
trenbe_2021_08_50 = {}
for word, counts in trenbe_2021_08_count.most_common(max):
    trenbe_2021_08_50[word] = counts
    print(f'{word} : {counts}')
# Out:
# 자꾸 : 18
# 계속 : 17
# 화면 : 14
# 업데이트 : 13
# 구매 : 10
# 상품 : 9
# 어플 : 9
# 로딩 : 8
# 오늘 : 8
# 진짜 : 6
# 사진 : 6
# 버튼 : 6
# 그냥 : 6
# 벨트 : 6
# 다른 : 5
# 주문 : 5
# 쇼핑 : 4
# 물건 : 4
# 수가 : 4
# 장바구니 : 4
# 요즘 : 4
# 다시 : 4
# 사이트 : 4
# 짜증 : 4
# 아이폰 : 4
# 정도 : 4
# 최악 : 4
# 문의 : 4
# 취소 : 4
# 안내 : 4
# 전혀 : 4
# 자주 : 3
# 현상 : 3
# 이번 : 3
# 시간 : 3
# 품절 : 3
# 가지 : 3
# 정말 : 2
# 버전 : 2
# 심해 : 2
# 보기 : 2
# 먹통 : 2
# 노트 : 2
# 홈페이지 : 2
# 마찬가지 : 2
# 처음 : 2
# 겨우 : 2
# 하나 : 2
# 간장 : 2
# 트래비 : 2

# %%
plt.figure(figsize=(10, 5))
plt.title('트랜비 2021.08 부정 단어 상위 (%d개)' % max, fontsize=12
         )    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in trenbe_2021_08_50.items():

    plt.bar(key, value, color='lightgrey') 
plt.show()

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(trenbe_2021_08_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
trenbe_app_202108 = trenbe_2021_08[trenbe_2021_08["category"]=='앱 오류']
trenbe_app_202108
# Out:
#       platform   store      date  \
# 6241    trenbe  google  20210831
# 6245    trenbe  google  20210830
# 6246    trenbe  google  20210830
# 6247    trenbe  google  20210830
# 6248    trenbe  google  20210830
# ...        ...     ...       ...
# 12304   trenbe  google  20210826
# 12315   trenbe   apple  20210824
# 12316   trenbe   apple  20210824
# 12365   trenbe   apple  20210818
# 12477   trenbe  google  20210809
#
#                                                   review  rating category  \
# 6241             업데이트하고 나서 정말 느려졌어요  그전 버전이 훨 빠르고 좋아요 ㅠㅠ       2     앱 오류
# 6245                          아 쇼핑 하는데 너무 답답해요 계속 화면 멈추고       2     앱 오류
# 6246                                앱이자꾸멈추고안되는데 물건을어째사죠        1     앱 오류
# 6247                                               렉 심해요       2     앱 오류
# 6248                                       렉이 진짜 심하네요 ㅠㅠ       1     앱 오류
# ...                                                  ...     ...      ...
# 12304                                 누가 업데이트 잘못 친 것 같은데       1     앱 오류
# 12315  사고싶은 게 있어서 다운받았는데 하얀색 화면만 뜨고 그 다음으로 넘어가질 않네요 네...       3     앱 오류
# 12316                                          들어가도 안 떠요       3     앱 오류
# 12365                              아이폰인데 분정도기다리면 첫화면뜨네요하       1     앱 오류
# 12477  업데이터 하면 장바구니 기록지워지고 다시 로그인 설정해야되는 뭐 같은 경우를 왜 사...       1     앱 오류
#
#        label
# 6241       0
# 6245       0
# 6246       0
# 6247       0
# 6248       0
# ...      ...
# 12304      0
# 12315      0
# 12316      0
# 12365      0
# 12477      0
#
# [83 rows x 7 columns]

# %%
trenbe_app_202108_nouns = []
for cmt in trenbe_app_202108['review']:
    trenbe_app_202108_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
trenbe_app_202108_nouns2 = []
word = [w for w in trenbe_app_202108_nouns if len(w) > 1]  
trenbe_app_202108_nouns2.extend(word)

# %%
trenbe_app_202108_nouns2
# Out:
# ['업데이트',
#  '정말',
#  '버전',
#  '쇼핑',
#  '계속',
#  '화면',
#  '자꾸',
#  '물건',
#  '심해',
#  '진짜',
#  '사진',
#  '화면',
#  '계속',
#  '로딩',
#  '버튼',
#  '오늘',
#  '업데이트',
#  '상품',
#  '보기',
#  '먹통',
#  '버튼',
#  '노트',
#  '상품',
#  '수가',
#  '홈페이지',
#  '자주',
#  '마찬가지',
#  '구매',
#  '처음',
#  '겨우',
#  '사진',
#  '하나',
#  '간장',
#  '트래비',
#  '자꾸',
#  '화면',
#  '현상',
#  '계속',
#  '계속',
#  '사용',
#  '진짜',
#  '이번',
#  '업데이트',
#  '속도',
#  '클릭',
#  '다시',
#  '시작',
#  '아주',
#  '어플',
#  '업뎃후',
#  '화면',
#  '자꾸',
#  '이미지',
#  '안보',
#  '스크롤바',
#  '리뷰',
#  '퍼센트',
#  '조치',
#  '계속',
#  '뭔가',
#  '업데이트',
#  '인내심',
#  '테스트',
#  '거참',
#  '쓰레기',
#  '진짜',
#  '로딩',
#  '무오',
#  '로딩',
#  '시간',
#  '상품',
#  '금액',
#  '자꾸',
#  '로딩',
#  '손좀',
#  '구매',
#  '화면',
#  '업데이트',
#  '가기',
#  '어플',
#  '사진',
#  '아이폰',
#  '다른',
#  '수정',
#  '원래',
#  '오늘',
#  '기능',
#  '계속',
#  '업뎃',
#  '누가',
#  '업데이트',
#  '잘못',
#  '다운',
#  '하얀색',
#  '화면',
#  '다음',
#  '네이버',
#  '사이트',
#  '기분',
#  '아이폰',
#  '정도',
#  '화면',
#  '데이터',
#  '장바구니',
#  '기록',
#  '다시',
#  '로그인',
#  '설정',
#  '경우',
#  '사전',
#  '고지',
#  '업데이트',
#  '정말',
#  '계속',
#  '화면',
#  '자꾸',
#  '물건',
#  '심해',
#  '진짜',
#  '사진',
#  '화면',
#  '계속',
#  '로딩',
#  '버튼',
#  '오늘',
#  '업데이트',
#  '상품',
#  '보기',
#  '먹통',
#  '홈페이지',
#  '자주',
#  '마찬가지',
#  '처음',
#  '겨우',
#  '사진',
#  '하나',
#  '간장',
#  '트래비',
#  '자꾸',
#  '화면',
#  '현상',
#  '계속',
#  '계속',
#  '진짜',
#  '이번',
#  '업데이트',
#  '속도',
#  '장바구니',
#  '그냥',
#  '허위',
#  '물건',
#  '사고',
#  '요즘',
#  '클릭',
#  '다시',
#  '시작',
#  '아주',
#  '어플',
#  '이번',
#  '업데이트',
#  '현상',
#  '자주',
#  '발생',
#  '어플',
#  '계속',
#  '다른',
#  '러신',
#  '조취를',
#  '어제',
#  '오늘',
#  '자꾸',
#  '다른',
#  '업뎃후',
#  '화면',
#  '자꾸',
#  '이미지',
#  '안보',
#  '스크롤바',
#  '리뷰',
#  '퍼센트',
#  '조치',
#  '사이트',
#  '계속',
#  '뭔가',
#  '업데이트',
#  '인내심',
#  '테스트',
#  '거참',
#  '쓰레기',
#  '짜증',
#  '자꾸',
#  '요즘',
#  '진짜',
#  '로딩',
#  '무오',
#  '로딩',
#  '시간',
#  '튕겨',
#  '쇼핑',
#  '어플',
#  '계속',
#  '어플',
#  '계속',
#  '짜증',
#  '구매',
#  '버튼',
#  '안눌리',
#  '상품',
#  '금액',
#  '자꾸',
#  '로딩',
#  '손좀',
#  '구매',
#  '화면',
#  '업데이트',
#  '가기',
#  '어플',
#  '사진',
#  '아이폰',
#  '다른',
#  '수정',
#  '뭘좀',
#  '상세',
#  '페이',
#  '도안',
#  '그냥',
#  '자꾸',
#  '사려',
#  '고해',
#  '자꾸',
#  '크롬',
#  '인터넷',
#  '자꾸',
#  '원래',
#  '오늘',
#  '기능',
#  '계속',
#  '업뎃',
#  '누가',
#  '업데이트',
#  '잘못',
#  '다운',
#  '하얀색',
#  '화면',
#  '다음',
#  '네이버',
#  '사이트',
#  '아이폰',
#  '정도',
#  '화면',
#  '요하',
#  '데이터',
#  '장바구니',
#  '기록',
#  '다시',
#  '로그인',
#  '설정',
#  '경우',
#  '사전',
#  '고지']

# %%
# Counter 객체 생성
trenbe_app_202108_count = Counter(trenbe_app_202108_nouns2)

# %%
max = 10
trenbe_app_202108_10 = {}
for word, counts in trenbe_app_202108_count.most_common(max):
    trenbe_app_202108_10[word] = counts
    print(f'{word} : {counts}')
# Out:
# 계속 : 15
# 화면 : 14
# 업데이트 : 13
# 자꾸 : 13
# 로딩 : 8
# 어플 : 7
# 진짜 : 6
# 사진 : 6
# 오늘 : 5
# 상품 : 5

# %%
plt.figure(figsize=(10, 5))
plt.title('트랜비 2021.08 앱오류 부정 단어 상위 (%d개)' % max, fontsize=12
         )    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in trenbe_app_202108_10.items():

    plt.bar(key, value, color='lightgrey') 
plt.show()

# %%
font_path =  '/System/Library/Fonts/Supplemental/AppleGothic.ttf'

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(trenbe_app_202108_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 확실히 2021.08에는 업데이트 때문에 앱 오류가 발생한 것이 맞아서 부정 리뷰가 많아짐.

# %% [markdown]
# ### 트렌비 2021.10
# - 앱 오류가 지나치가 많음

# %%
trenbe_2021_10 = trenbe[trenbe['date'].str.contains('202110')]
trenbe_2021_10
# Out:
#       platform   store      date  \
# 5590    trenbe   apple  20211031
# 5591    trenbe   apple  20211031
# 5599    trenbe  google  20211030
# 5614    trenbe   apple  20211030
# 5615    trenbe   apple  20211030
# ...        ...     ...       ...
# 12043   trenbe   apple  20211004
# 12044   trenbe   apple  20211004
# 12052   trenbe   apple  20211001
# 12053   trenbe   apple  20211001
# 12054   trenbe   apple  20211001
#
#                                                   review  rating   category  \
# 5590                                             흰화면 입니다       1       앱 오류
# 5591   안녕하세요 아이폰x인데 잘사용하다가 몇주전부터 실행이안되네요 삭제했다가 설치하는데도...       1       앱 오류
# 5599              쑤뤠기인데..? 결국 70퍼 이상 할인 뭐 이런건 죄다 중고아녀...       1    가격&프로모션
# 5614   상품에 문제가있어서 반품하려니 뭐가이리 까다로워요 반품할려구 챗봇 고객센터 이용할려...       1       고객센터
# 5615                        구매내역 확인이 안된다 이정도면 서비스하지 말아야지       1     만족도&기타
# ...                                                  ...     ...        ...
# 12043  그로인해 아직 다른 상품이 있는 거 아니냐 여쭤봤는데 그부분에 대해 답변은 주시지않...       1       고객센터
# 12044         트렌비믿고 구매한적은 있었지만 찜찜한 답변은 신뢰를 약간 떨어뜨리게 만드네요       1       고객센터
# 12052                       특정 상품명을 검색하면 무슨 말도 안나오게 검색돼요       1  UX/UI 편의성
# 12053  언제까지 어플이 이렇게 버벅댈건지 모르겠네요 들어가서 좀 보다보면 흰색화면 몇번 보...       1       앱 오류
# 12054                           년이 지나도 불안한데 고칠 생각은 없는건가요       1     만족도&기타
#
#        label
# 5590       0
# 5591       0
# 5599       0
# 5614       0
# 5615       0
# ...      ...
# 12043      0
# 12044      0
# 12052      0
# 12053      0
# 12054      0
#
# [195 rows x 7 columns]

# %%
trenbe_2021_10['review'] = trenbe_2021_10['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))
# Out:
# /var/folders/58/gn_xg82n3_d5871yqsk64tm40000gn/T/ipykernel_5080/3234711767.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trenbe_2021_10['review'] = trenbe_2021_10['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
trenbe_2021_10_nouns = []
for cmt in trenbe_2021_10['review']:
    trenbe_2021_10_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
trenbe_2021_10_nouns2 = []
word = [w for w in trenbe_2021_10_nouns if len(w) > 1]  
trenbe_2021_10_nouns2.extend(word)

# %%
trenbe_2021_10_nouns2
# Out:
# ['화면',
#  '아이폰',
#  '주전',
#  '실행',
#  '삭제',
#  '설치',
#  '언제',
#  '쑤뤠기',
#  '이상',
#  '할인',
#  '중고',
#  '상품',
#  '문제',
#  '반품',
#  '반품',
#  '챗봇',
#  '고객',
#  '센터',
#  '이용',
#  '반품',
#  '기능',
#  '문제',
#  '상품',
#  '반품',
#  '사용',
#  '안함',
#  '완전',
#  '은기',
#  '확인',
#  '정도',
#  '서비스',
#  '자주',
#  '가짐',
#  '안정화',
#  '회원',
#  '가입',
#  '쿠폰',
#  '다운',
#  '이유',
#  '어플',
#  '기본',
#  '기능',
#  '대체',
#  '다운',
#  '삭제',
#  '트렌비',
#  '물건',
#  '물건',
#  '반품',
#  '이상',
#  '택배',
#  '응대',
#  '명품',
#  '개도',
#  '절대',
#  '무슨',
#  '직구도',
#  '여기',
#  '이용',
#  '다운',
#  '삭제',
#  '다시',
#  '다운',
#  '어플',
#  '골프',
#  '카테고리',
#  '스크롤',
#  '갑자기',
#  '화면',
#  '몇번',
#  '반복',
#  '어플',
#  '자꾸',
#  '시작',
#  '메인',
#  '화면',
#  '다시',
#  '계속',
#  '상반',
#  '고해',
#  '계속',
#  '메인',
#  '화면',
#  '페이지',
#  '상품',
#  '혼자',
#  '계속',
#  '메인',
#  '지금',
#  '어플',
#  '다른',
#  '페이지',
#  '구경',
#  '정도',
#  '메인',
#  '화면',
#  '계속',
#  '확인',
#  '접속',
#  '로딩',
#  '와이파이',
#  '데이터',
#  '시도',
#  '로딩',
#  '삭제',
#  '설치',
#  '멋대로',
#  '처음',
#  '화면',
#  '검색',
#  '상품',
#  '검색',
#  '구경',
#  '갑자기',
#  '처음',
#  '화면',
#  '버튼',
#  '잘못',
#  '다시',
#  '검색',
#  '한지',
#  '초도',
#  '멋대로',
#  '처음',
#  '화면',
#  '구경',
#  '만듬',
#  '삭제',
#  '보고',
#  '리세',
#  '일도',
#  '하루',
#  '몇번',
#  '진짜',
#  '한번',
#  '그냥',
#  '화면',
#  '다시',
#  '그때',
#  '개선',
#  '버그',
#  '카테고리',
#  '브랜드',
#  '화면',
#  '계속',
#  '보라',
#  '그냥',
#  '사용',
#  '삭제',
#  '리뷰',
#  '가방',
#  '구매',
#  '기제',
#  '완료',
#  '취소',
#  '상태',
#  '이기',
#  '주가',
#  '주문',
#  '취소',
#  '연락',
#  '고지도',
#  '일방',
#  '취소',
#  '쿠폰',
#  '막상',
#  '무엇',
#  '안정',
#  '개판',
#  '상품',
#  '보고',
#  '계속',
#  '화면',
#  '튕기',
#  '현상',
#  '와우',
#  '오온',
#  '로렉스',
#  '검색',
#  '시세',
#  '정도',
#  '어플',
#  '순삭',
#  '그냥',
#  '가격',
#  '어플',
#  '구경',
#  '자꾸',
#  '갑자기',
#  '순간',
#  '어플',
#  '어플',
#  '믿음',
#  '로그인',
#  '김우빈',
#  '캐스팅',
#  '정도',
#  '개선',
#  '그냥',
#  '화면',
#  '어플',
#  '업데이트',
#  '실행',
#  '이안',
#  '계속',
#  '최신',
#  '버전',
#  '업데이트',
#  '하라',
#  '해결',
#  '업데이트',
#  '실행',
#  '업데이트',
#  '네트워크',
#  '오류',
#  '오픈',
#  '참여',
#  '업데이트',
#  '버튼',
#  '물건',
#  '진행',
#  '상황',
#  '파악',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '계속',
#  '어플',
#  '업데이트',
#  '안내',
#  '접속',
#  '자꾸',
#  '업데이트',
#  '하라',
#  '하나요',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '해도',
#  '진짜',
#  '트렌비',
#  '어플',
#  '업데이트',
#  '질병',
#  '업데이트',
#  '하라',
#  '고해',
#  '가짐',
#  '업데이트',
#  '계속',
#  '가짐',
#  '고객',
#  '센터',
#  '연락',
#  '약관',
#  '때문',
#  '별일',
#  '안내',
#  '확인',
#  '연락',
#  '무소식',
#  '실행',
#  '업로드',
#  '하라',
#  '구글플레이',
#  '업뎃할',
#  '계속',
#  '업데이트',
#  '하라',
#  '계속',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '접속',
#  '멘트',
#  '검증',
#  '접속',
#  '업데이트',
#  '업데이트',
#  '알람',
#  '접속',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '수정',
#  '문의',
#  '반품',
#  '사람',
#  '공감',
#  '광고',
#  '사이트',
#  '그냥',
#  '업데이트',
#  '접속',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '원단',
#  '상세',
#  '설명',
#  '사진',
#  '사이즈',
#  '대충',
#  '사이즈',
#  '가이드',
#  '사이즈',
#  '원단',
#  '상세',
#  '확대',
#  '확대',
#  '업데이트',
#  '업데이트',
#  '해도',
#  '최악',
#  '남성',
#  '제품',
#  '취소',
#  '취소',
#  '반품',
#  '비용',
#  '고객',
#  '부담',
#  '사과',
#  '내용',
#  '개선',
#  '문의',
#  '해도',
#  '콜센터',
#  '직원',
#  '메뉴얼',
#  '대응',
#  '해쥬시',
#  '매우',
#  '형식',
#  '업데이트',
#  '계속',
#  '접속',
#  '업데이트',
#  '해도',
#  '삭제',
#  '설치',
#  '업데이트',
#  '자꾸',
#  '사이트',
#  '가짐',
#  '업데이트',
#  '업데이트',
#  '평소',
#  '에러',
#  '반응속도',
#  '기도',
#  '사용',
#  '현금영수증',
#  '문의',
#  '답변',
#  '업데이트',
#  '업뎃',
#  '튕깁니',
#  '전반',
#  '표기',
#  '할인',
#  '거품',
#  '사후',
#  '서비스',
#  '그냥',
#  '백화점',
#  '가면',
#  '바로',
#  '해주',
#  '가품',
#  '구별',
#  '구별',
#  '최악',
#  '반품',
#  '신청',
#  '한지',
#  '일주일',
#  '상품',
#  '게시',
#  '대표',
#  '전화',
#  '상담',
#  '진심',
#  '최악',
#  '계속',
#  '다운',
#  '바구니',
#  '장바구니',
#  '버튼',
#  '자꾸',
#  '화면',
#  '이동',
#  '결제',
#  '쿠폰',
#  '증정',
#  '점검',
#  '화면',
#  '계속',
#  '깜빡',
#  '거리',
#  '자동',
#  '현상',
#  '탐색',
#  '조차',
#  '개선',
#  '제품',
#  '검수',
#  '상품',
#  '불량',
#  '현지',
#  '출고',
#  '교환',
#  '도움',
#  '물류',
#  '센터',
#  '재고',
#  '소진',
#  '마지막',
#  '상품',
#  '사이트',
#  '상품',
#  '그로',
#  '다른',
#  '상품',
#  '부분',
#  '대해',
#  '답변',
#  '주시',
#  '교환',
#  '환불',
#  '절차',
#  '진행',
#  '답변',
#  '트렌비믿',
#  '한적',
#  '답변',
#  '신뢰',
#  '약간',
#  '특정',
#  '상품',
#  '검색',
#  '무슨',
#  '검색',
#  '언제',
#  '어플',
#  '흰색',
#  '화면',
#  '몇번',
#  '보고',
#  '몇번',
#  '언제',
#  '개선',
#  '생각',
#  '가요',
#  '화면',
#  '아이폰',
#  '주전',
#  '실행',
#  '삭제',
#  '설치',
#  '언제',
#  '쑤뤠기',
#  '이상',
#  '할인',
#  '중고',
#  '상품',
#  '문제',
#  '반품',
#  '반품',
#  '챗봇',
#  '고객',
#  '센터',
#  '이용',
#  '반품',
#  '기능',
#  '문제',
#  '상품',
#  '반품',
#  '사용',
#  '안함',
#  '완전',
#  '은기',
#  '확인',
#  '정도',
#  '서비스',
#  '자주',
#  '가짐',
#  '안정화',
#  '회원',
#  '입도',
#  '쿠폰',
#  '다운',
#  '이유',
#  '어플',
#  '기본',
#  '기능',
#  '대체',
#  '다운',
#  '삭제',
#  '트렌비',
#  '물건',
#  '물건',
#  '반품',
#  '이상',
#  '택배',
#  '응대',
#  '명품',
#  '개도',
#  '절대',
#  '무슨',
#  '직구도',
#  '여기',
#  '이용',
#  '다운',
#  '삭제',
#  '다시',
#  '다운',
#  '어플',
#  '골프',
#  '카테고리',
#  '스크롤',
#  '갑자기',
#  '화면',
#  '몇번',
#  '반복',
#  '어플',
#  '자꾸',
#  '시작',
#  '메인',
#  '화면',
#  '다시',
#  '계속',
#  '상반',
#  '고해',
#  '계속',
#  '메인',
#  '화면',
#  '페이지',
#  '상품',
#  '혼자',
#  '계속',
#  '메인',
#  '지금',
#  '어플',
#  '다른',
#  '페이지',
#  '구경',
#  '정도',
#  '메인',
#  '화면',
#  '계속',
#  '확인',
#  '오류',
#  '관리',
#  '접속',
#  '로딩',
#  '와이파이',
#  '데이터',
#  '시도',
#  '로딩',
#  '삭제',
#  '설치',
#  '로딩',
#  '멋대로',
#  '처음',
#  '화면',
#  '검색',
#  '상품',
#  '검색',
#  '구경',
#  '갑자기',
#  '처음',
#  '화면',
#  '버튼',
#  '잘못',
#  '다시',
#  '검색',
#  '한지',
#  '초도',
#  '멋대로',
#  '처음',
#  '화면',
#  '구경',
#  '만듬',
#  '삭제',
#  '진짜',
#  '한번',
#  '그냥',
#  '화면',
#  '다시',
#  '그때',
#  '개선',
#  '버그',
#  '카테고리',
#  '브랜드',
#  '화면',
#  '계속',
#  '보라',
#  '그냥',
#  '사용',
#  '삭제',
#  '리뷰',
#  '가방',
#  '구매',
#  '기제',
#  '완료',
#  '취소',
#  '상태',
#  '이기',
#  '주가',
#  '주문',
#  '취소',
#  '연락',
#  '고지도',
#  '일방',
#  '취소',
#  '쿠폰',
#  '막상',
#  '무엇',
#  '안정',
#  '개판',
#  '상품',
#  '보고',
#  '계속',
#  '화면',
#  '튕기',
#  '현상',
#  '와우',
#  '오온',
#  '로렉스',
#  '검색',
#  '시세',
#  '정도',
#  '어플',
#  '순삭',
#  '그냥',
#  '가격',
#  '믿음',
#  '로그인',
#  '김우빈',
#  '캐스팅',
#  '정도',
#  '개선',
#  '다만',
#  '표기',
#  '한번',
#  '한국',
#  '표기',
#  '제일',
#  '먼저',
#  '그냥',
#  '화면',
#  '어플',
#  '업데이트',
#  '실행',
#  '이안',
#  '계속',
#  '최신',
#  '버전',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '실행',
#  '업데이트',
#  '네트워크',
#  '오류',
#  '오픈',
#  '참여',
#  '업데이트',
#  '열기',
#  '버튼',
#  '물건',
#  '진행',
#  '상황',
#  '파악',
#  '신뢰',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '계속',
#  '어플',
#  '업데이트',
#  '안내',
#  '접속',
#  '자꾸',
#  '업데이트',
#  '하라',
#  '하나요',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '해도',
#  '진짜',
#  '트렌비',
#  '어플',
#  '업데이트',
#  '질병',
#  '업데이트',
#  '하라',
#  '고해',
#  '가짐',
#  '업데이트',
#  '계속',
#  '가짐',
#  '상품',
#  '월일',
#  '주문',
#  '월일',
#  '수령',
#  '안내',
#  '일인',
#  '오늘',
#  '지바',
#  '고객',
#  '센터',
#  '연락',
#  '약관',
#  '때문',
#  '별일',
#  '안내',
#  '확인',
#  '연락',
#  '무소식',
#  '최소한',
#  '티비',
#  '광고',
#  '정도',
#  '투자',
#  '보기',
#  '투자자',
#  '바보',
#  '고객',
#  '관리',
#  '기업',
#  '무엇',
#  '투자',
#  '실행',
#  '업로드',
#  '하라',
#  '구글플레이',
#  '업뎃할',
#  '계속',
#  '업데이트',
#  '라면',
#  '안보',
#  '업데이트',
#  '하라',
#  '계속',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '접속',
#  '멘트',
#  '검증',
#  '접속',
#  '업데이트',
#  '하라',
#  '계속',
#  '접속',
#  '아예',
#  '업데이트',
#  '업데이트',
#  '알람',
#  '접속',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '수정',
#  '반품',
#  '문의',
#  '사람',
#  '공감',
#  '광고',
#  '사이트',
#  '업데이트',
#  '가요',
#  '그냥',
#  '업데이트',
#  '접속',
#  '신발',
#  '사이즈',
#  '국내',
#  '표시',
#  '구매',
#  '입장',
#  '선택',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '대체',
#  '대체',
#  '어플',
#  '쿠폰',
#  '때문',
#  '그것',
#  '어플',
#  '존재',
#  '이유',
#  '원단',
#  '상세',
#  '설명',
#  '사진',
#  '사이즈',
#  '대충',
#  '사이즈',
#  '가이드',
#  '사이즈',
#  '원단',
#  '상세',
#  '확대',
#  '확대',
#  '업데이트',
#  '업데이트',
#  '어플',
#  '리지',
#  '계속',
#  '업데이트',
#  '문구',
#  '확인',
#  '부탁',
#  '업데이트',
#  '해도',
#  '최악',
#  '브랜드',
#  '고객',
#  '불만',
#  '콧등',
#  '커플',
#  '신발',
#  '주문',
#  '남성',
#  '제품',
#  '취소',
#  '취소',
#  '남성',
#  '제품',
#  '취소',
#  '반품',
#  '비용',
#  '고객',
#  '부담',
#  '사과',
#  '내용',
#  '개선',
#  '얼마나',
#  '브랜드',
#  '억이',
#  '투자',
#  '고객',
#  '확보',
#  '임원',
#  '인건비',
#  '문의',
#  '해도',
#  '콜센터',
#  '직원',
#  '메뉴얼',
#  '대응',
#  '해쥬시',
#  '매우',
#  '형식',
#  '트랜비',
#  '전혀',
#  '개입',
#  '피해',
#  '고스',
#  '고객',
#  '업데이트',
#  '계속',
#  '접속',
#  '업데이트',
#  '해도',
#  '삭제',
#  '설치',
#  '업데이트',
#  '자꾸',
#  '사이트',
#  '가짐',
#  '업데이트',
#  '업데이트',
#  '평소',
#  '에러',
#  '반응속도',
#  '기도',
#  '사용',
#  '업데이트',
#  '업뎃',
#  '튕깁니',
#  '현금영수증',
#  '문의',
#  '답변',
#  '전반',
#  '표기',
#  '할인',
#  '거품',
#  '기준',
#  '책정',
#  '시계',
#  '구매',
#  '무려',
#  '프로',
#  '할인',
#  '가격',
#  '혜택',
#  '백화점',
#  '공식',
#  '그냥',
#  '상시',
#  '판매',
#  '가격',
#  '비슷',
#  '오히려',
#  '여러',
#  '혜택',
#  '백화점',
#  '이득',
#  '사후',
#  '서비스',
#  '그냥',
#  '백화점',
#  '가면',
#  '바로',
#  '해주',
#  '최악',
#  '상품',
#  '게시',
#  '반품',
#  '신청',
#  '한지',
#  '일주일',
#  '대표',
#  '전화',
#  '상담',
#  '진심',
#  '최악',
#  '계속',
#  '다운',
#  '바구니',
#  '장바구니',
#  '버튼',
#  '자꾸',
#  '화면',
#  '이동',
#  '결제',
#  '쿠폰',
#  '증정',
#  '점검',
#  '화면',
#  '계속',
#  '깜빡',
#  '거리',
#  '자동',
#  '현상',
#  '탐색',
#  '조차',
#  '개선',
#  '제품',
#  '검수',
#  '상품',
#  '불량',
#  '현지',
#  '출고',
#  '교환',
#  '도움',
#  '물류',
#  '센터',
#  '재고',
#  '소진',
#  '마지막',
#  '상품',
#  '사이트',
#  '상품',
#  '그로',
#  '다른',
#  '상품',
#  '부분',
#  '대해',
#  '답변',
#  '주시',
#  '교환',
#  '환불',
#  '절차',
#  '진행',
#  '답변',
#  '트렌비믿',
#  '한적',
#  '답변',
#  '신뢰',
#  '약간',
#  '특정',
#  '상품',
#  '검색',
#  '무슨',
#  '검색',
#  '언제',
#  '어플',
#  ...]

# %%
# Counter 객체 생성
trenbe_2021_10_count = Counter(trenbe_2021_10_nouns2)

# %%
max = 50
trenbe_2021_10_50 = {}
for word, counts in trenbe_2021_10_count.most_common(max):
    trenbe_2021_10_50[word] = counts
    print(f'{word} : {counts}')
# Out:
# 업데이트 : 71
# 계속 : 36
# 화면 : 30
# 어플 : 24
# 상품 : 23
# 하라 : 17
# 반품 : 16
# 접속 : 15
# 삭제 : 14
# 그냥 : 13
# 검색 : 12
# 취소 : 11
# 고객 : 10
# 다운 : 10
# 개선 : 10
# 정도 : 9
# 자꾸 : 9
# 실행 : 8
# 가짐 : 8
# 다시 : 8
# 메인 : 8
# 해도 : 8
# 답변 : 8
# 확인 : 7
# 쿠폰 : 7
# 몇번 : 7
# 구경 : 7
# 사이즈 : 7
# 설치 : 6
# 언제 : 6
# 센터 : 6
# 사용 : 6
# 물건 : 6
# 처음 : 6
# 버튼 : 6
# 연락 : 6
# 문의 : 6
# 사이트 : 6
# 최악 : 6
# 할인 : 5
# 갑자기 : 5
# 로딩 : 5
# 보고 : 5
# 안내 : 5
# 제품 : 5
# 이상 : 4
# 문제 : 4
# 이용 : 4
# 기능 : 4
# 서비스 : 4

# %%
plt.figure(figsize=(10, 5))
plt.title('트랜비 2021.10 부정 단어 상위 (%d개)' % max, fontsize=12
         )    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in trenbe_2021_10_50.items():

    plt.bar(key, value, color='lightgrey') 
plt.show()

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(trenbe_2021_10_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
trenbe_app_202110 = trenbe_2021_10[trenbe_2021_10["category"]=='앱 오류']
trenbe_app_202110
# Out:
#       platform   store      date  \
# 5590    trenbe   apple  20211031
# 5591    trenbe   apple  20211031
# 5650    trenbe  google  20211027
# 5651    trenbe   apple  20211027
# 5652    trenbe   apple  20211027
# ...        ...     ...       ...
# 11874   trenbe  google  20211014
# 12033   trenbe  google  20211005
# 12034   trenbe  google  20211004
# 12035   trenbe  google  20211004
# 12053   trenbe   apple  20211001
#
#                                                   review  rating category  \
# 5590                                             흰화면 입니다       1     앱 오류
# 5591   안녕하세요 아이폰 인데 잘사용하다가 몇주전부터 실행이안되네요 삭제했다가 설치하는데도...       1     앱 오류
# 5650                     앱이 자주 안 들어가짐 내가 앱 안정화하는게 더 빠를 듯       1     앱 오류
# 5651                                    회원가입도 쿠폰다운도 다 안됨       1     앱 오류
# 5652                            이걸 쓰는 이유를  다 막아버림 걍 다 안됨       1     앱 오류
# ...                                                  ...     ...      ...
# 11874                    들어와보니 업데이트하라고 해서 업뎃하려니 안되고 튕깁니다       1     앱 오류
# 12033                                   앱이 계속 다운되고 불편하네요       2     앱 오류
# 12034  징바구니 넣어놨는데 장바구니 찜하기 버튼 누르면 자꾸 홈화면으로 이동돼요 앱으로 결...       1     앱 오류
# 12035       화면이 계속 깜빡거리고 홈으로 자동 돌아가는 현상이 있어 탐색 조차 불가능하네요       1     앱 오류
# 12053  언제까지 어플이 이렇게 버벅댈건지 모르겠네요 들어가서 좀 보다보면 흰색화면 몇번 보...       1     앱 오류
#
#        label
# 5590       0
# 5591       0
# 5650       0
# 5651       0
# 5652       0
# ...      ...
# 11874      0
# 12033      0
# 12034      0
# 12035      0
# 12053      0
#
# [109 rows x 7 columns]

# %%
trenbe_app_202110_nouns = []
for cmt in trenbe_app_202110['review']:
    trenbe_app_202110_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
trenbe_app_202110_nouns2 = []
word = [w for w in trenbe_app_202110_nouns if len(w) > 1]  
trenbe_app_202110_nouns2.extend(word)

# %%
trenbe_app_202110_nouns2
# Out:
# ['화면',
#  '아이폰',
#  '주전',
#  '실행',
#  '삭제',
#  '설치',
#  '언제',
#  '자주',
#  '가짐',
#  '안정화',
#  '회원',
#  '가입',
#  '쿠폰',
#  '다운',
#  '이유',
#  '어플',
#  '기본',
#  '기능',
#  '대체',
#  '다운',
#  '삭제',
#  '다운',
#  '삭제',
#  '다시',
#  '다운',
#  '어플',
#  '골프',
#  '카테고리',
#  '스크롤',
#  '갑자기',
#  '화면',
#  '몇번',
#  '반복',
#  '어플',
#  '자꾸',
#  '시작',
#  '메인',
#  '화면',
#  '다시',
#  '계속',
#  '상반',
#  '고해',
#  '계속',
#  '메인',
#  '화면',
#  '지금',
#  '어플',
#  '다른',
#  '페이지',
#  '구경',
#  '정도',
#  '메인',
#  '화면',
#  '계속',
#  '확인',
#  '접속',
#  '로딩',
#  '와이파이',
#  '데이터',
#  '시도',
#  '로딩',
#  '삭제',
#  '설치',
#  '멋대로',
#  '처음',
#  '화면',
#  '검색',
#  '상품',
#  '검색',
#  '구경',
#  '갑자기',
#  '처음',
#  '화면',
#  '버튼',
#  '잘못',
#  '다시',
#  '검색',
#  '한지',
#  '초도',
#  '멋대로',
#  '처음',
#  '화면',
#  '구경',
#  '만듬',
#  '삭제',
#  '보고',
#  '리세',
#  '일도',
#  '하루',
#  '몇번',
#  '진짜',
#  '한번',
#  '그냥',
#  '화면',
#  '다시',
#  '그때',
#  '개선',
#  '버그',
#  '카테고리',
#  '브랜드',
#  '화면',
#  '계속',
#  '보라',
#  '그냥',
#  '사용',
#  '삭제',
#  '리뷰',
#  '가방',
#  '구매',
#  '기제',
#  '완료',
#  '취소',
#  '상태',
#  '이기',
#  '주가',
#  '주문',
#  '취소',
#  '연락',
#  '고지도',
#  '일방',
#  '취소',
#  '쿠폰',
#  '막상',
#  '무엇',
#  '안정',
#  '개판',
#  '상품',
#  '보고',
#  '계속',
#  '화면',
#  '튕기',
#  '현상',
#  '로그인',
#  '김우빈',
#  '캐스팅',
#  '정도',
#  '개선',
#  '그냥',
#  '화면',
#  '어플',
#  '업데이트',
#  '실행',
#  '이안',
#  '계속',
#  '최신',
#  '버전',
#  '업데이트',
#  '하라',
#  '해결',
#  '업데이트',
#  '실행',
#  '업데이트',
#  '네트워크',
#  '오류',
#  '오픈',
#  '참여',
#  '업데이트',
#  '버튼',
#  '물건',
#  '진행',
#  '상황',
#  '파악',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '계속',
#  '어플',
#  '업데이트',
#  '안내',
#  '접속',
#  '자꾸',
#  '업데이트',
#  '하라',
#  '하나요',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '해도',
#  '진짜',
#  '트렌비',
#  '어플',
#  '업데이트',
#  '질병',
#  '업데이트',
#  '하라',
#  '고해',
#  '가짐',
#  '업데이트',
#  '계속',
#  '가짐',
#  '실행',
#  '업로드',
#  '하라',
#  '구글플레이',
#  '업뎃할',
#  '계속',
#  '업데이트',
#  '하라',
#  '계속',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '접속',
#  '멘트',
#  '검증',
#  '접속',
#  '업데이트',
#  '업데이트',
#  '알람',
#  '접속',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '수정',
#  '업데이트',
#  '접속',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '원단',
#  '상세',
#  '설명',
#  '사진',
#  '사이즈',
#  '대충',
#  '사이즈',
#  '가이드',
#  '사이즈',
#  '원단',
#  '상세',
#  '확대',
#  '확대',
#  '업데이트',
#  '업데이트',
#  '해도',
#  '최악',
#  '업데이트',
#  '계속',
#  '접속',
#  '업데이트',
#  '해도',
#  '삭제',
#  '설치',
#  '업데이트',
#  '자꾸',
#  '사이트',
#  '가짐',
#  '업데이트',
#  '업데이트',
#  '평소',
#  '에러',
#  '반응속도',
#  '기도',
#  '사용',
#  '현금영수증',
#  '문의',
#  '답변',
#  '업데이트',
#  '업뎃',
#  '튕깁니',
#  '계속',
#  '다운',
#  '바구니',
#  '장바구니',
#  '버튼',
#  '자꾸',
#  '화면',
#  '이동',
#  '결제',
#  '쿠폰',
#  '증정',
#  '점검',
#  '화면',
#  '계속',
#  '깜빡',
#  '거리',
#  '자동',
#  '현상',
#  '탐색',
#  '조차',
#  '개선',
#  '특정',
#  '상품',
#  '검색',
#  '무슨',
#  '검색',
#  '언제',
#  '어플',
#  '흰색',
#  '화면',
#  '몇번',
#  '보고',
#  '몇번',
#  '언제',
#  '개선',
#  '생각',
#  '가요',
#  '화면',
#  '아이폰',
#  '주전',
#  '실행',
#  '삭제',
#  '설치',
#  '언제',
#  '자주',
#  '가짐',
#  '안정화',
#  '회원',
#  '입도',
#  '쿠폰',
#  '다운',
#  '어플',
#  '기본',
#  '기능',
#  '대체',
#  '다운',
#  '다운',
#  '삭제',
#  '다시',
#  '다운',
#  '어플',
#  '골프',
#  '카테고리',
#  '스크롤',
#  '갑자기',
#  '화면',
#  '몇번',
#  '반복',
#  '어플',
#  '자꾸',
#  '시작',
#  '메인',
#  '화면',
#  '다시',
#  '계속',
#  '상반',
#  '고해',
#  '계속',
#  '메인',
#  '화면',
#  '지금',
#  '어플',
#  '다른',
#  '페이지',
#  '구경',
#  '정도',
#  '메인',
#  '화면',
#  '계속',
#  '오류',
#  '관리',
#  '접속',
#  '로딩',
#  '와이파이',
#  '데이터',
#  '시도',
#  '로딩',
#  '삭제',
#  '설치',
#  '로딩',
#  '멋대로',
#  '처음',
#  '화면',
#  '검색',
#  '상품',
#  '검색',
#  '구경',
#  '갑자기',
#  '처음',
#  '화면',
#  '버튼',
#  '잘못',
#  '다시',
#  '검색',
#  '한지',
#  '초도',
#  '멋대로',
#  '처음',
#  '화면',
#  '구경',
#  '만듬',
#  '삭제',
#  '진짜',
#  '한번',
#  '그냥',
#  '화면',
#  '다시',
#  '그때',
#  '개선',
#  '버그',
#  '카테고리',
#  '브랜드',
#  '화면',
#  '계속',
#  '보라',
#  '쿠폰',
#  '막상',
#  '무엇',
#  '안정',
#  '개판',
#  '상품',
#  '보고',
#  '계속',
#  '화면',
#  '튕기',
#  '현상',
#  '로그인',
#  '김우빈',
#  '캐스팅',
#  '정도',
#  '개선',
#  '그냥',
#  '화면',
#  '어플',
#  '업데이트',
#  '실행',
#  '이안',
#  '계속',
#  '최신',
#  '버전',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '실행',
#  '업데이트',
#  '네트워크',
#  '오류',
#  '오픈',
#  '참여',
#  '업데이트',
#  '열기',
#  '버튼',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '계속',
#  '어플',
#  '업데이트',
#  '안내',
#  '접속',
#  '자꾸',
#  '업데이트',
#  '하라',
#  '하나요',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '해도',
#  '진짜',
#  '트렌비',
#  '어플',
#  '업데이트',
#  '질병',
#  '업데이트',
#  '하라',
#  '고해',
#  '가짐',
#  '업데이트',
#  '계속',
#  '가짐',
#  '실행',
#  '업로드',
#  '하라',
#  '구글플레이',
#  '업뎃할',
#  '계속',
#  '업데이트',
#  '라면',
#  '안보',
#  '업데이트',
#  '하라',
#  '계속',
#  '업데이트',
#  '하라',
#  '업데이트',
#  '접속',
#  '멘트',
#  '검증',
#  '접속',
#  '업데이트',
#  '하라',
#  '계속',
#  '접속',
#  '아예',
#  '업데이트',
#  '업데이트',
#  '알람',
#  '접속',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '업데이트',
#  '가요',
#  '업데이트',
#  '접속',
#  '업데이트',
#  '계속',
#  '업데이트',
#  '대체',
#  '어플',
#  '업데이트',
#  '업데이트',
#  '어플',
#  '리지',
#  '계속',
#  '업데이트',
#  '문구',
#  '업데이트',
#  '해도',
#  '최악',
#  '업데이트',
#  '계속',
#  '접속',
#  '업데이트',
#  '해도',
#  '삭제',
#  '설치',
#  '업데이트',
#  '자꾸',
#  '사이트',
#  '가짐',
#  '업데이트',
#  '업데이트',
#  '평소',
#  '에러',
#  '반응속도',
#  '기도',
#  '업데이트',
#  '업뎃',
#  '튕깁니',
#  '계속',
#  '다운',
#  '바구니',
#  '장바구니',
#  '버튼',
#  '자꾸',
#  '화면',
#  '이동',
#  '결제',
#  '쿠폰',
#  '증정',
#  '점검',
#  '화면',
#  '계속',
#  '깜빡',
#  '거리',
#  '자동',
#  '현상',
#  '탐색',
#  '조차',
#  '언제',
#  '어플',
#  '흰색',
#  '화면',
#  '몇번',
#  '보고',
#  '몇번',
#  '언제',
#  '개선']

# %%
# Counter 객체 생성
trenbe_app_202110_count = Counter(trenbe_app_202110_nouns2)

# %%
max = 10
trenbe_app_202110_10 = {}
for word, counts in trenbe_app_202110_count.most_common(max):
    trenbe_app_202110_10[word] = counts
    print(f'{word} : {counts}')
# Out:
# 업데이트 : 71
# 계속 : 34
# 화면 : 30
# 어플 : 18
# 하라 : 17
# 접속 : 15
# 삭제 : 12
# 다운 : 10
# 실행 : 8
# 가짐 : 8

# %%
plt.figure(figsize=(10, 5))
plt.title('트랜비 2021.10 앱오류 부정 단어 상위 (%d개)' % max, fontsize=12
         )    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in trenbe_app_202110_10.items():

    plt.bar(key, value, color='lightgrey') 
plt.show()

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(trenbe_app_202110_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ###  2021.10에도 업데이트 때문에 앱 오류가 발생한 것이 맞아서 부정 리뷰가 많아짐

# %% [markdown]
# ### 트렌비 2021.08_2021.11 만족도&기타, 고객센터 > 어떤 부분이 불만족스러웠는지 확인

# %%
trenbe_2021_08 = trenbe[trenbe['date'].str.contains('202108')]

# %%
trenbe_2021_09 = trenbe[trenbe['date'].str.contains('202109')]

# %%
trenbe_2021_10 = trenbe[trenbe['date'].str.contains('202110')]

# %%
trenbe_2021_11 = trenbe[trenbe['date'].str.contains('202111')]

# %%
trenbe_2021_08_11 = pd.concat([trenbe_2021_08,trenbe_2021_09,trenbe_2021_10,trenbe_2021_11])

# %%
trenbe_2021_08_11
# Out:
#       platform   store      date                                   review  \
# 6241    trenbe  google  20210831  업데이트하고 나서 정말 느려졌어요. 그전 버전이 훨 빠르고 좋아요.ㅠㅠ
# 6245    trenbe  google  20210830               아 쇼핑 하는데 너무 답답해요 계속 화면 멈추고
# 6246    trenbe  google  20210830                     앱이자꾸멈추고안되는데 물건을어째사죠?
# 6247    trenbe  google  20210830                                    렉 심해요
# 6248    trenbe  google  20210830                            렉이 진짜 심하네요 ㅠㅠ
# ...        ...     ...       ...                                      ...
# 11141   trenbe  google  20211103             물건 우겨넣고 취소수수료로 장사하는 쓰레기기업입니다
# 11210   trenbe   apple  20211102                     현지바잉중 주째 떠서 그냥 취소했어요
# 11211   trenbe   apple  20211102        현지바잉이 너무 오래 지속되면 구매자랑 연락이 되면 좋겠어요
# 11212   trenbe   apple  20211102                          취소할지말지 버튼도 없고ㅠㅠ
# 11220   trenbe  google  20211101              초마다 로딩해서 홈 화면으로 감 사용자체가 불가능
#
#        rating   category  label
# 6241        2       앱 오류      0
# 6245        2       앱 오류      0
# 6246        1       앱 오류      0
# 6247        2       앱 오류      0
# 6248        1       앱 오류      0
# ...       ...        ...    ...
# 11141       1    가격&프로모션      0
# 11210       2      상품 구색      0
# 11211       2       고객센터      0
# 11212       2  UX/UI 편의성      0
# 11220       1       앱 오류      0
#
# [598 rows x 7 columns]

# %%
trenbe_2021_08_11_cus = trenbe_2021_08_11[trenbe_2021_08_11["category"]=='고객센터']

# %%
trenbe_2021_08_11_sat = trenbe_2021_08_11[trenbe_2021_08_11["category"]=='만족도&기타']

# %%
trenbe_2021_08_11_sur = pd.concat([trenbe_2021_08_11_cus,trenbe_2021_08_11_sat])

# %%
trenbe_2021_08_11_sur
# Out:
#       platform   store      date  \
# 6372    trenbe  google  20210813
# 6413    trenbe   apple  20210807
# 6451    trenbe   apple  20210802
# 12619   trenbe   apple  20210802
# 6127    trenbe   apple  20210930
# ...        ...     ...       ...
# 11060   trenbe  google  20211105
# 11129   trenbe  google  20211103
# 11132   trenbe  google  20211103
# 11137   trenbe  google  20211103
# 11140   trenbe  google  20211103
#
#                                                   review  rating category  \
# 6372   최악최악... 제품이 너무 안 와서 문의했는데 판매처 누락으로 취소해야 한다고 합니...       1     고객센터
# 6413   안내도 없이 품절됐다며 주문한 상품 5가지를 한꺼번에 그냥 취소해버리네요 5개나 품...       1     고객센터
# 6451   벨트를 주문했는데 분명 남성->악세서리-> 벨트 이렇게 되있는데 오늘 벨트를 받고 ...       1     고객센터
# 12619                                전화를 몇번이나 드려도 안받으시네요       1     고객센터
# 6127               개인정보유출, 배송지연, 허위광고, CS대응 등 모든 것이 다 최악       1     고객센터
# ...                                                  ...     ...      ...
# 11060                                     이거 마이너스는 없는건가요       1   만족도&기타
# 11129                                        정말 이상한 곳이예요       1   만족도&기타
# 11132  그러면서 교환 반품은 안된다네요 참나 책임지지 않으려는 꼼수도 여러가지네요 조카랑 ...       1   만족도&기타
# 11137                                           진짜 최악입니다       1   만족도&기타
# 11140                                         절대 이용하지마세요       1   만족도&기타
#
#        label
# 6372       0
# 6413       0
# 6451       0
# 12619      0
# 6127       0
# ...      ...
# 11060      0
# 11129      0
# 11132      0
# 11137      0
# 11140      0
#
# [192 rows x 7 columns]

# %%
trenbe_2021_08_11_sur['review'] = trenbe_2021_08_11_sur['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
trenbe_2021_08_11_sur_nouns = []
for cmt in trenbe_2021_08_11_sur['review']:
    trenbe_2021_08_11_sur_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
trenbe_2021_08_11_sur_nouns2 = []
word = [w for w in trenbe_2021_08_11_sur_nouns if len(w) > 1]  
trenbe_2021_08_11_sur_nouns2.extend(word)

# %%
trenbe_2021_08_11_sur_nouns2
# Out:
# ['최악',
#  '최악',
#  '제품',
#  '문의',
#  '판매',
#  '누락',
#  '취소',
#  '정도',
#  '사안',
#  '문의',
#  '연락',
#  '처리',
#  '안내',
#  '품절',
#  '주문',
#  '상품',
#  '가지',
#  '그냥',
#  '취소',
#  '품절',
#  '주문',
#  '그것',
#  '구매',
#  '가지',
#  '상품',
#  '거지',
#  '확률',
#  '구매',
#  '품목',
#  '환불',
#  '안내',
#  '전혀',
#  '전혀',
#  '사기',
#  '벨트',
#  '주문',
#  '분명',
#  '남성',
#  '벨트',
#  '오늘',
#  '벨트',
#  '여자',
#  '사이즈',
#  '제대로',
#  '표기',
#  '반품',
#  '교환',
#  '물품',
#  '전화',
#  '몇번',
#  '전화',
#  '몇번',
#  '개인정보',
#  '유출',
#  '배송',
#  '지연',
#  '허위',
#  '광고',
#  '대응',
#  '모든',
#  '최악',
#  '배송',
#  '지연',
#  '연락',
#  '직접',
#  '문의',
#  '문제',
#  '제기',
#  '신뢰',
#  '어플',
#  '개인정보',
#  '유출',
#  '메일',
#  '사람',
#  '백화점',
#  '이유',
#  '하자',
#  '상품',
#  '사진',
#  '상품',
#  '제외',
#  '재고',
#  '관계',
#  '환불',
#  '처리',
#  '통보',
#  '광고',
#  '화가',
#  '소비자보호원',
#  '신고',
#  '고객',
#  '권리',
#  '해도',
#  '그때',
#  '계속',
#  '전화',
#  '제발',
#  '제발',
#  '제발',
#  '이용',
#  '도안',
#  '직접',
#  '최악',
#  '진품',
#  '인지도',
#  '의문',
#  '에루샤',
#  '얼마',
#  '후속',
#  '대응',
#  '별로',
#  '얼마',
#  '상품',
#  '하자',
#  '요청',
#  '담당자',
#  '연결',
#  '연결',
#  '답변',
#  '가능',
#  '여부',
#  '대한',
#  '답변',
#  '일단',
#  '주가',
#  '에루샤',
#  '마침내',
#  '대행',
#  '본사',
#  '수리',
#  '트렌비',
#  '수선',
#  '업체',
#  '여기',
#  '의문',
#  '담당자',
#  '공개',
#  '후기',
#  '곳도',
#  '의문',
#  '진짜',
#  '다른',
#  '광고',
#  '경험',
#  '후기',
#  '대응',
#  '대비',
#  '최악',
#  '본인',
#  '택인',
#  '응대',
#  '지연',
#  '연관',
#  '인지',
#  '바람',
#  '인원',
#  '응대',
#  '퀄리티',
#  '자체',
#  '질문',
#  '요점',
#  '이해',
#  '기계',
#  '답변',
#  '도안',
#  '직접',
#  '에루샤',
#  '얼마',
#  '후속',
#  '대응',
#  '별로',
#  '얼마',
#  '상품',
#  '하자',
#  '요청',
#  '담당자',
#  '연결',
#  '연결',
#  '답변',
#  '가능',
#  '여부',
#  '대한',
#  '답변',
#  '일단',
#  '주가',
#  '담당자',
#  '응대',
#  '퀄리티',
#  '자체',
#  '질문',
#  '요점',
#  '이해',
#  '상품',
#  '문제',
#  '반품',
#  '반품',
#  '챗봇',
#  '고객',
#  '센터',
#  '이용',
#  '반품',
#  '기능',
#  '문제',
#  '상품',
#  '반품',
#  '사용',
#  '안함',
#  '완전',
#  '은기',
#  '무슨',
#  '직구도',
#  '여기',
#  '이용',
#  '고객',
#  '센터',
#  '연락',
#  '약관',
#  '때문',
#  '별일',
#  '안내',
#  '확인',
#  '연락',
#  '무소식',
#  '문의',
#  '반품',
#  '사람',
#  '공감',
#  '광고',
#  '사이트',
#  '그냥',
#  '남성',
#  '제품',
#  '취소',
#  '취소',
#  '반품',
#  '비용',
#  '고객',
#  '부담',
#  '사과',
#  '내용',
#  '개선',
#  '문의',
#  '해도',
#  '콜센터',
#  '직원',
#  '메뉴얼',
#  '대응',
#  '해쥬시',
#  '매우',
#  '형식',
#  '사후',
#  '서비스',
#  '그냥',
#  '백화점',
#  '가면',
#  '바로',
#  '해주',
#  '최악',
#  '반품',
#  '신청',
#  '한지',
#  '일주일',
#  '상품',
#  '게시',
#  '대표',
#  '전화',
#  '상담',
#  '진심',
#  '최악',
#  '제품',
#  '검수',
#  '상품',
#  '불량',
#  '현지',
#  '출고',
#  '교환',
#  '도움',
#  '물류',
#  '센터',
#  '재고',
#  '소진',
#  '마지막',
#  '상품',
#  '사이트',
#  '상품',
#  '그로',
#  '다른',
#  '상품',
#  '부분',
#  '대해',
#  '답변',
#  '주시',
#  '교환',
#  '환불',
#  '절차',
#  '진행',
#  '답변',
#  '트렌비믿',
#  '한적',
#  '답변',
#  '신뢰',
#  '약간',
#  '반품',
#  '명품',
#  '개도',
#  '절대',
#  '상품',
#  '월일',
#  '주문',
#  '월일',
#  '수령',
#  '안내',
#  '일인',
#  '오늘',
#  '지바',
#  '고객',
#  '센터',
#  '연락',
#  '약관',
#  '때문',
#  '별일',
#  '안내',
#  '확인',
#  '연락',
#  '무소식',
#  '문의',
#  '사람',
#  '공감',
#  '광고',
#  '사이트',
#  '문의',
#  '해도',
#  '콜센터',
#  '직원',
#  '메뉴얼',
#  '대응',
#  '해쥬시',
#  '매우',
#  '형식',
#  '현금영수증',
#  '문의',
#  '답변',
#  '대표',
#  '전화',
#  '상담',
#  '진심',
#  '최악',
#  '그로',
#  '다른',
#  '상품',
#  '부분',
#  '대해',
#  '답변',
#  '주시',
#  '교환',
#  '환불',
#  '절차',
#  '진행',
#  '답변',
#  '트렌비믿',
#  '한적',
#  '답변',
#  '신뢰',
#  '약간',
#  '마음대로',
#  '통화',
#  '품절',
#  '처리',
#  '서비스',
#  '대응',
#  '별하나',
#  '정품',
#  '의심',
#  '상세',
#  '접수',
#  '그냥',
#  '마지막',
#  '접수',
#  '문의',
#  '오프라인',
#  '모두',
#  '품절',
#  '물량없다',
#  '품절',
#  '연락',
#  '배송지',
#  '이나',
#  '판매',
#  '불가',
#  '사항',
#  '대해',
#  '판매',
#  '고지',
#  '의무',
#  '가요',
#  '사항',
#  '상품',
#  '취소',
#  '상담',
#  '주말',
#  '취소',
#  '다른',
#  '평가',
#  '나마',
#  '언제',
#  '답변',
#  '출석',
#  '체크',
#  '언제',
#  '스타벅스',
#  '쿠폰',
#  '가요',
#  '문자',
#  '가요',
#  '완료',
#  '주문',
#  '결제',
#  '완료',
#  '재고',
#  '취소',
#  '수만',
#  '말로',
#  '유관',
#  '부서',
#  '내용',
#  '전달',
#  '진짜',
#  '내용',
#  '유관',
#  '부서',
#  '토스',
#  '최소한',
#  '기본',
#  '족족',
#  '재고',
#  '취소',
#  '스트레스',
#  '그것',
#  '알람',
#  '카드',
#  '취소',
#  '기본',
#  '열흘',
#  '동네',
#  '슈퍼',
#  '주문',
#  '미련',
#  '오늘',
#  '부로',
#  '트랜비',
#  '주변',
#  '친구',
#  '직장',
#  '동료',
#  '가족',
#  '등등',
#  '트랜비',
#  '사용',
#  '적극',
#  '홍보',
#  '하나',
#  '사서',
#  '상태',
#  '별루',
#  '반품',
#  '청해',
#  '지금',
#  '통화',
#  '하루',
#  '종일',
#  '겨우',
#  '연락',
#  '물건',
#  '흘딱',
#  '어거지',
#  '소비자',
#  '입장',
#  '새똥',
#  '생각',
#  '소리',
#  '택배',
#  '기사',
#  '명도',
#  '진짜',
#  '최악',
#  '주문',
#  '취소',
#  '버튼',
#  '절차',
#  '허구',
#  '고객',
#  '센터',
#  '밥처',
#  '전화',
#  '담당자',
#  '세월',
#  '절대',
#  '이용',
#  '물건',
#  '취소',
#  '수수료',
#  '장사',
#  '쓰레기',
#  '기업',
#  '지바',
#  '그냥',
#  '취소',
#  '지바',
#  '지속',
#  '구매',
#  '자랑',
#  '연락',
#  '마음대로',
#  '통화',
#  '품절',
#  '처리',
#  '서비스',
#  '대응',
#  '별하나',
#  '반품',
#  '하루',
#  '완전',
#  '불만족',
#  '물량없다',
#  '품절',
#  '연락',
#  '배송지',
#  '이나',
#  '판매',
#  '불가',
#  '사항',
#  '대해',
#  '판매',
#  '고지',
#  '의무',
#  '가요',
#  '사항',
#  '상품',
#  '취소',
#  '상담',
#  '주말',
#  '취소',
#  '다른',
#  '평가',
#  '나마',
#  '언제',
#  '카드',
#  '연락',
#  '취소',
#  '반품',
#  '무조건',
#  '상담',
#  '유선',
#  '신청',
#  '챗봇',
#  '반품',
#  '버튼',
#  '해외',
#  '직구',
#  '국내',
#  '배송',
#  '반품',
#  '접수',
#  '반품',
#  '기한',
#  '시간',
#  '말로',
#  '유관',
#  '부서',
#  '내용',
#  '전달',
#  '지금',
#  '통화',
#  '하루',
#  '종일',
#  '겨우',
#  '연락',
#  '물건',
#  '흘딱',
#  '어거지',
#  '소비자',
#  '입장',
#  '새똥',
#  '생각',
#  '환불',
#  '구매',
#  '사이즈',
#  '대해',
#  '문의',
#  '무조건',
#  '자동',
#  '응답',
#  '해당',
#  '판매',
#  '직접',
#  '고객',
#  '센터',
#  '밥처',
#  '전화',
#  '담당자',
#  '세월',
#  '지바',
#  '지속',
#  '구매',
#  '자랑',
#  '연락',
#  '수가',
#  '요즘',
#  '어제',
#  '오늘',
#  '자꾸',
#  '다른',
#  '사이트',
#  '짜증',
#  '자꾸',
#  '요즘',
#  '쇼핑',
#  '어플',
#  '계속',
#  '버전',
#  '쇼핑',
#  '수가',
#  '노트',
#  '상품',
#  '수가',
#  '구매',
#  '별하나',
#  '최악',
#  '최악',
#  '제품',
#  '문의',
#  '판매',
#  '누락',
#  '취소',
#  '정도',
#  '사안',
#  '문의',
#  '연락',
#  '처리',
#  '안내',
#  '품절',
#  '주문',
#  '상품',
#  '가지',
#  '그냥',
#  '취소',
#  '안내',
#  '전혀',
#  '벨트',
#  '주문',
#  '분명',
#  '남성',
#  '벨트',
#  '오늘',
#  '벨트',
#  '여자',
#  '오늘',
#  '주식',
#  '추천',
#  '리딩',
#  '신청',
#  '초대',
#  '전화',
#  '때문',
#  '보완',
#  '신경',
#  '당장',
#  '삭제',
#  '개인정보',
#  '삭제',
#  '관리',
#  '부분',
#  '정말',
#  '엉망',
#  '달후',
#  '박음질',
#  '자꾸',
#  '이건',
#  '건가',
#  '문제',
#  '제기',
#  '신뢰',
#  '어플',
#  '개인정보',
#  '유출',
#  '메일',
#  '사람',
#  '백화점',
#  '이유',
#  '하자',
#  '상품',
#  '사진',
#  '상품',
#  '제외',
#  '재고',
#  '관계',
#  '환불',
#  '처리',
#  '통보',
#  '광고',
#  '화가',
#  '소비자보호원',
#  '신고',
#  '고객',
#  '권리',
#  '해도',
#  '그때',
#  '계속',
#  '전화',
#  '제발',
#  '제발',
#  '제발',
#  '이용',
#  '오늘',
#  '주식',
#  '추천',
#  '리딩',
#  '신청',
#  '초대',
#  '전화',
#  '때문',
#  '보완',
#  '신경',
#  '당장',
#  '삭제',
#  '개인정보',
#  '삭제',
#  '관리',
#  '부분',
#  '정말',
#  '엉망',
#  '달후',
#  '박음질',
#  '당황',
#  '트렌비',
#  '수선',
#  '업체',
#  '여기',
#  '의문',
#  '계속',
#  '다시',
#  '소프트웨어',
#  '서비스',
#  '대응',
#  '대비',
#  '최악',
#  '본인',
#  '택인',
#  '응대',
#  '지연',
#  '연관',
#  '인지',
#  '바람',
#  '인원',
#  '자꾸',
#  '이건',
#  '건가',
#  '버전',
#  '이상',
#  '개선',
#  '분동',
#  '시간',
#  '확인',
#  '정도',
#  '서비스',
#  '페이지',
#  '상품',
#  '혼자',
#  '계속',
#  '메인',
#  '어플',
#  '구경',
#  '자꾸',
#  '갑자기',
#  '순간',
#  '어플',
#  '어플',
#  '확인',
#  '정도',
#  '서비스',
#  '이유',
#  '삭제',
#  '트렌비',
#  '물건',
#  '무슨',
#  '직구도',
#  '여기',
#  '이용',
#  '페이지',
#  '상품',
#  '혼자',
#  '계속',
#  '메인',
#  '확인',
#  '그냥',
#  '사용',
#  '삭제',
#  '리뷰',
#  '연락',
#  '고지도',
#  '일방',
#  '취소',
#  '물건',
#  '진행',
#  '상황',
#  '파악',
#  '신뢰',
#  '최소한',
#  '티비',
#  '광고',
#  '정도',
#  '투자',
#  '보기',
#  '투자자',
#  '바보',
#  '고객',
#  '관리',
#  '기업',
#  '무엇',
#  '투자',
#  '수정',
#  '그냥',
#  '대체',
#  '확인',
#  '부탁',
#  '브랜드',
#  '고객',
#  '불만',
#  '콧등',
#  '커플',
#  '신발',
#  '주문',
#  '남성',
#  '제품',
#  '취소',
#  '취소',
#  '남성',
#  '제품',
#  '취소',
#  '억이',
#  '투자',
#  '고객',
#  '확보',
#  '임원',
#  '인건비',
#  '트랜비',
#  '전혀',
#  '개입',
#  '피해',
#  '고스',
#  '고객',
#  '사후',
#  '서비스',
#  '그냥',
#  '백화점',
#  '가면',
#  '바로',
#  '해주',
#  '최악',
#  '상품',
#  '게시',
#  '개선',
#  '생각',
#  '가요',
#  '출석',
#  '일부러',
#  '건가',
#  '출석',
#  '빙고',
#  '처리',
#  '요망',
#  '광고',
#  '광고',
#  '아치',
#  '아이폰',
#  '사용',
#  '자꾸',
#  '판매',
#  '상품',
#  '등록',
#  '결제',
#  '취소',
#  '판매',
#  '다시',
#  '결제',
#  '취소',
#  '세번',
#  '그냥',
#  '여기',
#  '구매',
#  '생각',
#  '발란',
#  '결제',
#  '바로',
#  '구매',
#  '어플',
#  '삭제',
#  '리뷰',
#  '보고',
#  '바로',
#  '삭제',
#  '알림',
#  '알림',
#  '리뷰',
#  '업체',
#  '알바',
#  '관리',
#  '하나요',
#  '개도',
#  '쓰레기',
#  '낚시',
#  '광고',
#  '지금',
#  '상품',
#  '낚시',
#  '인스타',
#  '팔로우',
#  '에러',
#  '체크',
#  '사기',
#  '최저',
#  '무슨',
#  '취소',
#  '그냥',
#  '장가',
#  '차라리',
#  '리뷰',
#  '보고',
#  '제거',
#  '진짜',
#  '그냥',
#  '쓰레기',
#  '그냥',
#  '웨이',
#  '광고',
#  '광고',
#  '아치',
#  '동안',
#  '팔지',
#  '아이폰',
#  '사용',
#  '자꾸',
#  '어플',
#  '삭제',
#  '리뷰',
#  '보고',
#  '바로',
#  '삭제',
#  '반품',
#  '교환',
#  '불가',
#  '경우',
#  '상품',
#  '구매',
#  '팩트',
#  '로만',
#  '등등',
#  '아픔',
#  '김희애',
#  '김우빈',
#  '이용',
#  '오프라인',
#  '광고',
#  '온에어',
#  '마케팅',
#  '비용',
#  '당신',
#  '서비스',
#  '개선',
#  '투자',
#  '진짜',
#  '내용',
#  '유관',
#  '부서',
#  '토스',
#  '최소한',
#  '기본',
#  '족족',
#  '재고',
#  '취소',
#  '스트레스',
#  '그것',
#  '알람',
#  '카드',
#  '취소',
#  '기본',
#  '열흘',
#  '동네',
#  '슈퍼',
#  '주문',
#  '미련',
#  '오늘',
#  '부로',
#  '트랜비',
#  '주변',
#  '친구',
#  '직장',
#  '동료',
#  '가족',
#  '등등',
#  ...]

# %%
# Counter 객체 생성
trenbe_2021_08_11_sur_count = Counter(trenbe_2021_08_11_sur_nouns2)

# %%
max = 50
trenbe_2021_08_11_sur_50 = {}
for word, counts in trenbe_2021_08_11_sur_count.most_common(max):
    trenbe_2021_08_50[word] = counts
    print(f'{word} : {counts}')
# Out:
# 상품 : 27
# 취소 : 26
# 반품 : 17
# 연락 : 15
# 최악 : 14
# 그냥 : 13
# 광고 : 13
# 답변 : 13
# 문의 : 12
# 고객 : 12
# 삭제 : 12
# 주문 : 11
# 전화 : 10
# 판매 : 9
# 구매 : 9
# 대응 : 9
# 어플 : 9
# 품절 : 8
# 오늘 : 8
# 이용 : 8
# 서비스 : 8
# 처리 : 7
# 안내 : 7
# 자꾸 : 7
# 제품 : 6
# 환불 : 6
# 벨트 : 6
# 교환 : 6
# 재고 : 6
# 계속 : 6
# 제발 : 6
# 담당자 : 6
# 진짜 : 6
# 다른 : 6
# 센터 : 6
# 사용 : 6
# 확인 : 6
# 가요 : 6
# 리뷰 : 6
# 정도 : 5
# 남성 : 5
# 개인정보 : 5
# 신뢰 : 5
# 여기 : 5
# 내용 : 5
# 바로 : 5
# 상담 : 5
# 대해 : 5
# 트랜비 : 5
# 물건 : 5

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(trenbe_2021_08_11_sur_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 키워드를 보면 연락 없이 품절 상품을 그냥 취소, 반품처리 때려버리는 거 같음.. 고객센터 대응, 답변도 최악?..

# %% [markdown]
# ### 트렌비 2021.12_2022.01 고객센터, 가격프로모션

# %%
trenbe_2021_09 = trenbe[trenbe['date'].str.contains('202109')]

# %%
trenbe_2021_11 = trenbe[trenbe['date'].str.contains('202111')]

# %%
trenbe_2021_12 = trenbe[trenbe['date'].str.contains('202112')]

# %%
trenbe_2022_01 = trenbe[trenbe['date'].str.contains('202201')]

# %%
trenbe_withoutapp = pd.concat([trenbe_2021_12, trenbe_2022_01,trenbe_2021_09,trenbe_2021_11 ])

# %%
trenbe_withoutapp
# Out:
#       platform   store      date                             review  rating  \
# 4329    trenbe  google  20211216                   고객사이트 연락이 너무 힘들다       3
# 4364    trenbe  google  20211216           별한개도 아까움 재고도없으면서 있다고 떠있고       1
# 4365    trenbe  google  20211216                   고객선터 연결은 기본20분이상       1
# 4366    trenbe  google  20211216                  주말포함10일기다림 5일배송인데       1
# 4374    trenbe  google  20211216     취소, 수정, 환불, 반품 버튼이 없어서 너무 불편해요       1
# ...        ...     ...       ...                                ...     ...
# 11141   trenbe  google  20211103       물건 우겨넣고 취소수수료로 장사하는 쓰레기기업입니다       1
# 11210   trenbe   apple  20211102               현지바잉중 주째 떠서 그냥 취소했어요       2
# 11211   trenbe   apple  20211102  현지바잉이 너무 오래 지속되면 구매자랑 연락이 되면 좋겠어요       2
# 11212   trenbe   apple  20211102                    취소할지말지 버튼도 없고ㅠㅠ       2
# 11220   trenbe  google  20211101        초마다 로딩해서 홈 화면으로 감 사용자체가 불가능       1
#
#         category  label
# 4329        고객센터      0
# 4364       상품 구색      0
# 4365        고객센터      0
# 4366          배송      0
# 4374   UX/UI 편의성      0
# ...          ...    ...
# 11141    가격&프로모션      0
# 11210      상품 구색      0
# 11211       고객센터      0
# 11212  UX/UI 편의성      0
# 11220       앱 오류      0
#
# [613 rows x 7 columns]

# %%
trenbe_2108_2201_cus = trenbe_withoutapp[trenbe_withoutapp["category"]=='고객센터']

# %%
trenbe_2108_2201_sat = trenbe_withoutapp[trenbe_withoutapp["category"]=='만족도&기타']

# %%
trenbe_withoutapp = pd.concat([trenbe_2108_2201_cus,trenbe_2108_2201_sat])

# %%
trenbe_withoutapp
# Out:
#       platform   store      date  \
# 4329    trenbe  google  20211216
# 4365    trenbe  google  20211216
# 4375    trenbe  google  20211216
# 4378    trenbe  google  20211216
# 4379    trenbe  google  20211216
# ...        ...     ...       ...
# 11060   trenbe  google  20211105
# 11129   trenbe  google  20211103
# 11132   trenbe  google  20211103
# 11137   trenbe  google  20211103
# 11140   trenbe  google  20211103
#
#                                                   review  rating category  \
# 4329                                    고객사이트 연락이 너무 힘들다       3     고객센터
# 4365                                    고객선터 연결은 기본20분이상       1     고객센터
# 4375          고객센터는 사람이 부족한건지 상담원분과 연결되기까지 시간을 너무 잡아먹습니다       1     고객센터
# 4378                      이거때문에 또 시간들여서 전화하기 너무 힘들 것 같네요       1     고객센터
# 4379                                       서비스가 너무 별로입니다       1     고객센터
# ...                                                  ...     ...      ...
# 11060                                     이거 마이너스는 없는건가요       1   만족도&기타
# 11129                                        정말 이상한 곳이예요       1   만족도&기타
# 11132  그러면서 교환 반품은 안된다네요 참나 책임지지 않으려는 꼼수도 여러가지네요 조카랑 ...       1   만족도&기타
# 11137                                           진짜 최악입니다       1   만족도&기타
# 11140                                         절대 이용하지마세요       1   만족도&기타
#
#        label
# 4329       0
# 4365       0
# 4375       0
# 4378       0
# 4379       0
# ...      ...
# 11060      0
# 11129      0
# 11132      0
# 11137      0
# 11140      0
#
# [305 rows x 7 columns]

# %%
trenbe_withoutapp['review'] = trenbe_withoutapp['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
trenbe_withoutapp_nouns = []
for cmt in trenbe_withoutapp['review']:
    trenbe_withoutapp_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
trenbe_withoutapp_nouns2 = []
word = [w for w in trenbe_withoutapp_nouns if len(w) > 1]  
trenbe_withoutapp_nouns2.extend(word)

# %%
trenbe_withoutapp_nouns2
# Out:
# ['고객',
#  '사이트',
#  '연락',
#  '객선',
#  '연결',
#  '기본',
#  '이상',
#  '고객',
#  '센터',
#  '사람',
#  '상담',
#  '분과',
#  '연결',
#  '시간',
#  '때문',
#  '시간',
#  '서비스',
#  '별로',
#  '주문',
#  '입금',
#  '반나절',
#  '입금',
#  '확인',
#  '환불',
#  '입금',
#  '확인',
#  '상담',
#  '보지',
#  '고객',
#  '센터',
#  '관련',
#  '문의',
#  '전화',
#  '시간',
#  '연결',
#  '대기',
#  '채팅',
#  '시간',
#  '대답',
#  '한마디',
#  '다시',
#  '하루',
#  '종일',
#  '답변',
#  '리퍼',
#  '여기저기',
#  '상처',
#  '손가락',
#  '지문',
#  '자국',
#  '덕지덕지',
#  '최악',
#  '밸트',
#  '연락처',
#  '주지',
#  '네이버',
#  '문의',
#  '구매',
#  '대행',
#  '고객',
#  '센터',
#  '전화',
#  '겨우',
#  '겨우',
#  '채팅',
#  '반품',
#  '신청',
#  '반품',
#  '택배',
#  '반품',
#  '연락',
#  '하루',
#  '온종일',
#  '자동',
#  '고객',
#  '센터',
#  '처리',
#  '전화',
#  '서비스',
#  '엉망',
#  '강제',
#  '환불',
#  '전화',
#  '상황',
#  '설명',
#  '사과',
#  '메시지',
#  '하나',
#  '그게',
#  '상품',
#  '리뷰',
#  '질문',
#  '채팅',
#  '고객',
#  '센터',
#  '로만',
#  '환불',
#  '대서',
#  '고객',
#  '센터',
#  '전화',
#  '하루',
#  '종일',
#  '연결',
#  '지금',
#  '순간',
#  '트렌',
#  '고객',
#  '센터',
#  '전화',
#  '환불',
#  '절차',
#  '운영',
#  '구매',
#  '신발',
#  '환불',
#  '고객',
#  '센터',
#  '제발',
#  '전화',
#  '애플',
#  '트랜비',
#  '다운',
#  '전체',
#  '화면',
#  '애플',
#  '고객',
#  '연락',
#  '이건',
#  '개발자',
#  '문의',
#  '하라',
#  '다시',
#  '전체',
#  '화면',
#  '업데이트',
#  '주심',
#  '깝깝해',
#  '무쟈',
#  '자주',
#  '쇼핑',
#  '고객',
#  '센터',
#  '엉망',
#  '전화',
#  '겨우',
#  '물건',
#  '예상',
#  '배송',
#  '일보',
#  '한참',
#  '입금',
#  '확인',
#  '상태',
#  '업체',
#  '문의',
#  '고객',
#  '센터',
#  '이틀',
#  '연속',
#  '한번',
#  '연락',
#  '요즘',
#  '곳도',
#  '새삼',
#  '고객',
#  '센터',
#  '전화',
#  '연결',
#  '절대',
#  '프리',
#  '클럽',
#  '업체',
#  '문의',
#  '고해',
#  '쇼핑몰',
#  '어플',
#  '에이',
#  '문의',
#  '별로',
#  '주문',
#  '연말',
#  '문의',
#  '구매',
#  '상품',
#  '취소',
#  '선물',
#  '타이밍',
#  '시간',
#  '미리',
#  '취소',
#  '문의',
#  '품절',
#  '안내',
#  '만원',
#  '리도',
#  '만원',
#  '명품',
#  '고객',
#  '센터',
#  '연결',
#  '최악',
#  '고객',
#  '센터',
#  '통화',
#  '전화',
#  '고객',
#  '센터',
#  '엉망',
#  '진짜',
#  '님들덕',
#  '잘피',
#  '고객',
#  '센터',
#  '연결',
#  '상담',
#  '채팅',
#  '하라',
#  '계속',
#  '결론',
#  '통화',
#  '연결',
#  '물건',
#  '도대체',
#  '언제',
#  '어디',
#  '서도',
#  '답변',
#  '고객',
#  '입장',
#  '상담',
#  '채팅',
#  '상담',
#  '연결',
#  '자금',
#  '광고',
#  '커스터',
#  '서비스',
#  '기본',
#  '가장',
#  '문제',
#  '고객',
#  '센터',
#  '상담',
#  '전화',
#  '연결',
#  '거의',
#  '포기',
#  '고객',
#  '센터',
#  '응대',
#  '처리',
#  '실질',
#  '판매',
#  '자가',
#  '처리',
#  '방법',
#  '시스템',
#  '고객',
#  '센터',
#  '연결',
#  '현재',
#  '판매',
#  '가방',
#  '지난주',
#  '주문',
#  '통장',
#  '주문',
#  '주문',
#  '물건',
#  '보유',
#  '오프라인',
#  '매장',
#  '재고',
#  '확인',
#  '이틀',
#  '연락',
#  '전화',
#  '전화',
#  '한번',
#  '통화량',
#  '그냥',
#  '제품',
#  '판매',
#  '어이',
#  '제발',
#  '업무',
#  '시간',
#  '통화',
#  '믿음',
#  '통화',
#  '전혀',
#  '연락처',
#  '문자',
#  '통화',
#  '한번',
#  '이따',
#  '구로',
#  '전화',
#  '문의',
#  '답변',
#  '구면',
#  '그냥',
#  '옷장',
#  '무슨',
#  '사이트',
#  '운영',
#  '거임',
#  '기분',
#  '기분',
#  '그냥',
#  '여기',
#  '전화',
#  '적도',
#  '그냥',
#  '고객',
#  '센터',
#  '고객',
#  '무시',
#  '복사',
#  '붙여넣기',
#  '답글',
#  '고객',
#  '사이트',
#  '연락',
#  '재고',
#  '객선',
#  '연결',
#  '기본',
#  '이상',
#  '고객',
#  '센터',
#  '사람',
#  '상담',
#  '분과',
#  '연결',
#  '시간',
#  '지연',
#  '사과',
#  '이건',
#  '상담',
#  '잘못',
#  '회사',
#  '상담',
#  '인원',
#  '때문',
#  '시간',
#  '기만',
#  '다인',
#  '가요',
#  '서비스',
#  '별로',
#  '굳이',
#  '여기',
#  '시간',
#  '환불',
#  '입금',
#  '확인',
#  '조치',
#  '상담',
#  '보지',
#  '지금',
#  '벙쪄',
#  '사기',
#  '건가',
#  '신고',
#  '고객',
#  '센터',
#  '관련',
#  '문의',
#  '전화',
#  '시간',
#  '연결',
#  '대기',
#  '채팅',
#  '시간',
#  '대답',
#  '한마디',
#  '다시',
#  '하루',
#  '종일',
#  '답변',
#  '확인',
#  '밸트',
#  '연락처',
#  '주지',
#  '네이버',
#  '문의',
#  '구매',
#  '대행',
#  '반품',
#  '트렌비',
#  '반품',
#  '판매',
#  '반품',
#  '판매',
#  '직접',
#  '트렌',
#  '이건',
#  '고객',
#  '센터',
#  '전화',
#  '겨우',
#  '겨우',
#  '채팅',
#  '반품',
#  '신청',
#  '반품',
#  '택배',
#  '반품',
#  '연락',
#  '하루',
#  '온종일',
#  '자동',
#  '김희애',
#  '선생님',
#  '목소리',
#  '성격',
#  '진짜',
#  '진짜',
#  '생각',
#  '정도',
#  '사람',
#  '심각',
#  '반품',
#  '완료',
#  '무조건',
#  '삭제',
#  '사람',
#  '고객',
#  '센터',
#  '처리',
#  '전화',
#  '서비스',
#  '엉망',
#  '강제',
#  '환불',
#  '전화',
#  '상황',
#  '설명',
#  '사과',
#  '메시지',
#  '하나',
#  '그게',
#  '상품',
#  '리뷰',
#  '질문',
#  '채팅',
#  '고객',
#  '센터',
#  '로만',
#  '환불',
#  '대서',
#  '고객',
#  '센터',
#  '전화',
#  '하루',
#  '종일',
#  '연결',
#  '광고',
#  '고객',
#  '센터',
#  '직원',
#  '고객',
#  '센터',
#  '직원',
#  '일부러',
#  '처럼',
#  '시간',
#  '동안',
#  '전화',
#  '어쩜',
#  '한번',
#  '영업',
#  '일일',
#  '환불',
#  '신청',
#  '시간',
#  '감정',
#  '낭비',
#  '전부',
#  '지금',
#  '순간',
#  '트렌',
#  '고객',
#  '센터',
#  '전화',
#  '환불',
#  '절차',
#  '운영',
#  '구매',
#  '신발',
#  '환불',
#  '고객',
#  '센터',
#  '제발',
#  '전화',
#  '고객',
#  '센터',
#  '엉망',
#  '전화',
#  '겨우',
#  '물건',
#  '예상',
#  '배송',
#  '일보',
#  '한참',
#  '입금',
#  '확인',
#  '상태',
#  '업체',
#  '문의',
#  '심지어',
#  '결제',
#  '버그',
#  '네이버',
#  '페이',
#  '직접',
#  '연락',
#  '결제',
#  '취소',
#  '시간',
#  '별하나',
#  '트렌비',
#  '고객',
#  '관리',
#  '최악',
#  '무슨',
#  '상담',
#  '로보트',
#  '동문서답',
#  '상담',
#  '묵묵',
#  '채팅',
#  '문의',
#  '답변',
#  '전화',
#  '연결',
#  '차례',
#  '시도',
#  '소비자',
#  '결제',
#  '끝입',
#  '환불',
#  '고생',
#  '고객',
#  '센터',
#  '연결',
#  '검수',
#  '사진',
#  '주말',
#  '고객',
#  '센터',
#  '연결',
#  '발송',
#  '하자',
#  '교환',
#  '검수',
#  '고가',
#  '물건',
#  '정리',
#  '고객',
#  '센터',
#  '연결',
#  '매우',
#  '어이',
#  '전화',
#  '연결',
#  '메세지',
#  '한참',
#  '안내',
#  '사항',
#  '내용',
#  '표기',
#  '답변',
#  '환율',
#  '등락',
#  '해외',
#  '사의',
#  '가격',
#  '조정',
#  '가격',
#  '변동',
#  '동일',
#  '상품',
#  '교환',
#  '경우',
#  '상품',
#  '가격',
#  '변동',
#  '결제',
#  '금액',
#  '차이',
#  '발생',
#  '내용',
#  '해석',
#  '조항',
#  '묶여서',
#  '항목',
#  '내용',
#  '문단',
#  '구매',
#  '가격',
#  '변동',
#  '얘기',
#  '교환',
#  '다른',
#  '가격',
#  '얘기',
#  '얘기',
#  '문장',
#  '각각',
#  '다른',
#  '내용',
#  '배송',
#  '변수',
#  '상황',
#  '안내',
#  '연락',
#  '택배',
#  '조치',
#  '한마디',
#  '한마디',
#  '사후관리',
#  '엉망',
#  '고객',
#  '문의',
#  '당시',
#  '이후',
#  '전혀',
#  '신경',
#  '상담',
#  '연결',
#  '어플',
#  '삭제',
#  '리뷰',
#  '보고',
#  '바로',
#  '삭제',
#  '요즘',
#  '세상',
#  '응대',
#  '누가',
#  '이용',
#  '보기',
#  '만해',
#  '판매',
#  '연락',
#  '똑바로',
#  '장사',
#  '죽겠네',
#  '상담',
#  '통화',
#  '상품',
#  '교환',
#  '전화',
#  '연결',
#  '챗봇',
#  '교환',
#  '문의',
#  '담날',
#  '챗봇',
#  '다시',
#  '문의',
#  '하라',
#  '계속',
#  '시간',
#  '나햇',
#  '통화량',
#  '타고',
#  '트렌비',
#  '마게',
#  '상품',
#  '교환',
#  '응답',
#  '상담',
#  '아주',
#  '아침',
#  '연락',
#  '무슨',
#  '퇴근',
#  '시반',
#  '상담',
#  '연락',
#  '아침',
#  '상담',
#  '예약',
#  '시스템',
#  '교환',
#  '환불',
#  '불가능',
#  '제품',
#  '태반',
#  '구입',
#  '사이즈',
#  '취소',
#  '불가능',
#  '상품',
#  '답변',
#  '소비자보호',
#  '연락',
#  '취소',
#  '답변',
#  '취소',
#  '비용',
#  '만원',
#  '이상',
#  '생각',
#  '물건',
#  '반송',
#  '한지',
#  '달반',
#  '깜깜무소식',
#  '의사',
#  '고객',
#  '센터',
#  '연결',
#  '답변',
#  '취소',
#  '불가능',
#  '진짜',
#  '고객',
#  '센터',
#  '연결',
#  '여기',
#  '쓰기',
#  '처음',
#  '광고',
#  '년도',
#  '인터넷',
#  '하루',
#  '중고',
#  '판매',
#  '과대',
#  '광고',
#  '신고',
#  '진짜',
#  '중고',
#  '하나',
#  '스트레스',
#  '지경',
#  '신청',
#  '지나',
#  '무소식',
#  '연결',
#  '코로나',
#  '급증',
#  '핑계',
#  '참나',
#  '어이',
#  '소비자보호원',
#  '신고',
#  '제발',
#  '고객',
#  '센터',
#  '전화',
#  '상담',
#  '연결',
#  '진짜',
#  '하루',
#  '꼬박',
#  '가격',
#  '잘못',
#  '게시',
#  '종종',
#  '상담',
#  '제품',
#  '구매',
#  '한지',
#  '주가',
#  '상품',
#  '처음',
#  '월일',
#  '가방',
#  '오지',
#  '콜센터',
#  '통화',
#  '수십',
#  '문의',
#  '도제',
#  '답변',
#  '도대체',
#  '달이',
#  '진짜',
#  '추천',
#  '진짜',
#  '업체',
#  '사이즈',
#  '선택',
#  '구매',
#  '일만',
#  '취소',
#  '이유',
#  '사이즈',
#  '품절',
#  '다시',
#  '상품',
#  '사이즈',
#  '품절',
#  '주문',
#  '가능',
#  '문의',
#  '게시판',
#  '재고',
#  '문의',
#  '취소',
#  '구매',
#  '만원',
#  '상당',
#  '쿠폰',
#  '때기',
#  '무분별',
#  '스팸',
#  '알람',
#  '주문',
#  '입금',
#  '품절',
#  '품절',
#  '배송',
#  '기간',
#  '확인',
#  '대응',
#  '품절',
#  '가격',
#  '친척',
#  '한번',
#  '바로',
#  '느낌',
#  '콜센터',
#  '모델',
#  '평가절하',
#  '업체',
#  '광고',
#  '모델',
#  '소속사',
#  '배우',
#  '이미지',
#  '아작',
#  '이번',
#  '연락',
#  '정말',
#  '전화',
#  '연결',
#  '일주일',
#  '내내',
#  '통화',
#  '아침',
#  '저녁',
#  '간격',
#  '언제',
#  '고객',
#  '센터',
#  '의도',
#  '카톡',
#  '고객',
#  '센터',
#  '문의',
#  '원인',
#  '개선',
#  '의지',
#  '콜센터',
#  '태도',
#  '기색',
#  '전혀',
#  '보이지',
#  '기계',
#  '안내',
#  '당신',
#  '결정',
#  '상황',
#  '고객',
#  '기분',
#  '낭비',
#  '시간',
#  '대해',
#  '조금',
#  '신경',
#  '필요',
#  '대처',
#  '제대로',
#  '별로',
#  '추천',
#  '배송',
#  '완료',
#  '상일',
#  '며칠',
#  '지난',
#  '시점',
#  '연락',
#  '고객',
#  '센터',
#  '취소',
#  '환불',
#  '문의',
#  '고객',
#  '센터',
#  '안내',
#  '하루',
#  '종일',
#  '대답',
#  '제품',
#  '리가',
#  '반품',
#  '기분',
#  '등등',
#  '금보',
#  '제대로',
#  '채팅',
#  '도움',
#  '하나',
#  '문의',
#  '내용',
#  '기타',
#  '채팅',
#  '상담',
#  '이용',
#  '하래',
#  '진짜',
#  '막장',
#  '환불',
#  '통보',
#  '고객',
#  '센터',
#  '영업',
#  '종료',
#  '시간',
#  '답변',
#  '판매',
#  '지역',
#  '코로나',
#  '때문',
#  '재고',
#  '통보',
#  '품절',
#  '환불',
#  '벌써',
#  '몇번',
#  '도대체',
#  '할인',
#  '상품',
#  '실컷',
#  '주문',
#  '하루',
#  '이틀',
#  '환불',
#  '기분',
#  '코로나',
#  '해도',
#  '하루',
#  '종일',
#  '일부러',
#  '생각',
#  '개인정보',
#  '유출',
#  '배송',
#  '지연',
#  '허위',
#  '광고',
#  '대응',
#  '모든',
#  '최악',
#  '배송',
#  '지연',
#  '연락',
#  '직접',
#  '문의',
#  '문제',
#  '제기',
#  '신뢰',
#  '어플',
#  '개인정보',
#  '유출',
#  '메일',
#  '사람',
#  '백화점',
#  '이유',
#  '하자',
#  '상품',
#  '사진',
#  '상품',
#  '제외',
#  '재고',
#  '관계',
#  '환불',
#  '처리',
#  '통보',
#  '광고',
#  '화가',
#  '소비자보호원',
#  '신고',
#  '고객',
#  '권리',
#  '해도',
#  '그때',
#  '계속',
#  '전화',
#  '제발',
#  '제발',
#  '제발',
#  '이용',
#  ...]

# %%
# Counter 객체 생성
trenbe_withoutapp_count = Counter(trenbe_withoutapp_nouns2)

# %%
max = 10
trenbe_withoutapp_10 = {}
for word, counts in trenbe_withoutapp_count.most_common(max):
    trenbe_withoutapp_10[word] = counts
    print(f'{word} : {counts}')
# Out:
# 고객 : 54
# 센터 : 43
# 전화 : 38
# 연결 : 33
# 취소 : 29
# 환불 : 25
# 문의 : 25
# 연락 : 23
# 상담 : 23
# 상품 : 23

# %%
plt.figure(figsize=(10, 5))
plt.title('트랜비 고객센터,만족도 부정 단어 상위 (%d개)' % max, fontsize=12
         )    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in trenbe_withoutapp_10.items():

    plt.bar(key, value, color='lightgrey') 
plt.show()

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(trenbe_withoutapp_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # 발란
# - 2021_2022년에 리뷰가 별로 없음에도 불구하고 부정 리뷰가 2023보다 많음.
# - 2023년에는 긍정 리뷰는 엄청 늘고, 전체 리뷰가 적었던 2021_2022보다 부정 리뷰 개수가 적음
# - 발란이 어떤 행보를 했길래 2023이 되면서 부정 리뷰가 줄어들었는지 확인 필요 (워드클라우드)
# - 2023 긍정 리뷰도 살짝 참고하면서 행보 구체화 (워드클라우드)> 보류
#     - 워드클라우드 2021_2022 만족도 앱오류 고객센터

# %%
# 발란
balaan = data_ne[data_ne["platform"]=='balaan']
balaan
# Out:
#       platform   store      date                            review  rating  \
# 3       balaan  google  20230914               포장이 안돼서 오는게 좀 그렇지만        5
# 30      balaan  google  20230912                 배송이 좀 늦어져서 짜증낫었는데       5
# 62      balaan  google  20230911            쿠폰 너무많뜸 쇼핑 불가할정도로 귀찮게함       1
# 65      balaan  google  20230911                     품절뜨면 가슴 찢어집니다       5
# 113     balaan  google  20230904  결재취소 안됨 일부러 오류나게 해놨는지 계속 오류뜸 쓰레기       1
# ...        ...     ...       ...                               ...     ...
# 12764   balaan  google  20210618                주말에도 당일배송 됐으면 좋겠어요       5
# 12784   balaan  google  20210615                   조금만 더 빨라지면 좋겠어요       5
# 12794   balaan  google  20210531                             최악입니다       1
# 12811   balaan  google  20210426                             최악이네요       1
# 12894   balaan  google  20210103                             최악입니다       1
#
#       category  label
# 3        상품 품질      0
# 30          배송      0
# 62     가격&프로모션      0
# 65       상품 구색      0
# 113       앱 오류      0
# ...        ...    ...
# 12764       배송      0
# 12784   만족도&기타      0
# 12794   만족도&기타      0
# 12811   만족도&기타      0
# 12894   만족도&기타      0
#
# [727 rows x 7 columns]

# %%
balaan['date']=balaan['date'].astype(str)
# Out:
# /var/folders/58/gn_xg82n3_d5871yqsk64tm40000gn/T/ipykernel_5080/2424093257.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balaan['date']=balaan['date'].astype(str)

# %%
balaan_21 = balaan[balaan['date'].str.contains('2021')]

# %%
balaan_22 = balaan[balaan['date'].str.contains('2022')]

# %%
balaan_21_22 = pd.concat([balaan_22, balaan_21])

# %%
balaan_21_22
# Out:
#       platform   store      date                                     review  \
# 2582    balaan  google  20221223                      오늘 출발이라면서 일째 출발 안 함ㅋㅋ
# 2592    balaan  google  20221221      알람 수신도안하는데 왜이렇게들 보내는겨 설정 찾기도 겁나어렵게해놓고
# 2603    balaan  google  20221218                        진짜 앱 개못만들었네 정신병걸리겠네
# 2604    balaan  google  20221217  별 도 아까움 명품케이스도 없는제품팔고 리뷰사진과 완전다르게와서 가품같다고
# 2605    balaan  google  20221217    협력업체 편만 들어서 환불요청했더니 반품비내라는 어이없는 발란업체입니다
# ...        ...     ...       ...                                        ...
# 12764   balaan  google  20210618                         주말에도 당일배송 됐으면 좋겠어요
# 12784   balaan  google  20210615                            조금만 더 빨라지면 좋겠어요
# 12794   balaan  google  20210531                                      최악입니다
# 12811   balaan  google  20210426                                      최악이네요
# 12894   balaan  google  20210103                                      최악입니다
#
#        rating   category  label
# 2582        1         배송      0
# 2592        1  UX/UI 편의성      0
# 2603        1  UX/UI 편의성      0
# 2604        1     정품 안전성      0
# 2605        1         배송      0
# ...       ...        ...    ...
# 12764       5         배송      0
# 12784       5     만족도&기타      0
# 12794       1     만족도&기타      0
# 12811       1     만족도&기타      0
# 12894       1     만족도&기타      0
#
# [636 rows x 7 columns]

# %%
balaan_21_22_app = balaan_21_22[balaan_21_22["category"]=='앱 오류']

# %%
balaan_21_22_sat = balaan_21_22[balaan_21_22["category"]=='만족도&기타']

# %%
balaan_21_22_sur = pd.concat([balaan_21_22_app, balaan_21_22_sat])

# %%
balaan_21_22_dil = balaan_21_22[balaan_21_22["category"]=='배송']

# %%
balaan_21_22_ux = balaan_21_22[balaan_21_22["category"]=='UX/UI 편의성']

# %%
balaan_21_22_ux_dil = pd.concat([balaan_21_22_dil, balaan_21_22_ux])

# %%
balaan_21_22_ux_dil
# Out:
#       platform   store      date  \
# 2582    balaan  google  20221223
# 2605    balaan  google  20221217
# 2608    balaan  google  20221216
# 2945    balaan  google  20221014
# 2980    balaan  google  20221005
# ...        ...     ...       ...
# 11376   balaan  google  20211027
# 11764   balaan  google  20211015
# 12517   balaan  google  20210807
# 12518   balaan  google  20210807
# 12744   balaan  google  20210621
#
#                                                   review  rating   category  \
# 2582                               오늘 출발이라면서 일째 출발 안 함ㅋㅋ       1         배송
# 2605             협력업체 편만 들어서 환불요청했더니 반품비내라는 어이없는 발란업체입니다       1         배송
# 2608                             반품하면 반품택배비로 수익창출 참 그지같다       1         배송
# 2945                             반품이나 사이즈교환시 비용이 만만치 않네요       1         배송
# 2980   오늘출발 주문했으나 이틀뒤 배송준비만 뜨더니 품절이라고 취소문자옴이용할일 도 없을거...       1         배송
# ...                                                  ...     ...        ...
# 11376  앱 안정성 매우떨어짐 중학생이 어플 만든듯한 퀄리티 이딴 쓰레기 앱 만들고 장사 쉽...       1  UX/UI 편의성
# 11764  제품 파는 사이트에서 확대가 안된다니뭘 자세히 볼수가 없고깨알같은 글씨 읽기 싫어서...       2  UX/UI 편의성
# 12517                 추가로 리뷰는 그 제품의 리뷰만 나오게 하시면 좋을 듯 싶네요       3  UX/UI 편의성
# 12518                                            난잡해보이네요       3  UX/UI 편의성
# 12744            신상과 최저가 찾기의 재미가 있음 랭킹이 좀 더 자주 바뀌었으면 좋겠음       5  UX/UI 편의성
#
#        label
# 2582       0
# 2605       0
# 2608       0
# 2945       0
# 2980       0
# ...      ...
# 11376      0
# 11764      0
# 12517      0
# 12518      0
# 12744      0
#
# [109 rows x 7 columns]

# %%
balaan_21_22_sur
# Out:
#       platform   store      date  \
# 2623    balaan  google  20221215
# 2624    balaan  google  20221215
# 2921    balaan  google  20221022
# 3077    balaan  google  20220922
# 3110    balaan  google  20220919
# ...        ...     ...       ...
# 12709   balaan  google  20210624
# 12784   balaan  google  20210615
# 12794   balaan  google  20210531
# 12811   balaan  google  20210426
# 12894   balaan  google  20210103
#
#                                                   review  rating category  \
# 2623   인터넷 결재하려는데 배송지 입럭다 되었는데 배송지 입력하라는 오류 계속 발생 상품도...       1     앱 오류
# 2624                  몇십만원어치 골라놨는데 결재가 안되어서 다른데에서 구매했습니다       1     앱 오류
# 2921                    도대체 로그인을 어떻게 하는건가요 로그인 페이지가 안나와요       1     앱 오류
# 3077   뒤로 가기 누르면 처음으로 돌아가는건 리뷰보니 작년부터있는 문제인데 고치지를 못하시...       1     앱 오류
# 3110                                           로그인이 안됩니다       1     앱 오류
# ...                                                  ...     ...      ...
# 12709                                결제 수단이 좀 더 늘었으면 합니다       5   만족도&기타
# 12784                                    조금만 더 빨라지면 좋겠어요       5   만족도&기타
# 12794                                              최악입니다       1   만족도&기타
# 12811                                              최악이네요       1   만족도&기타
# 12894                                              최악입니다       1   만족도&기타
#
#        label
# 2623       0
# 2624       0
# 2921       0
# 3077       0
# 3110       0
# ...      ...
# 12709      0
# 12784      0
# 12794      0
# 12811      0
# 12894      0
#
# [305 rows x 7 columns]

# %%
balaan_21_22_ux_dil['review'] = balaan_21_22_ux_dil['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
balaan_21_22_ux_dil_nouns = []
for cmt in balaan_21_22_ux_dil['review']:
    balaan_21_22_ux_dil_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
balaan_21_22_ux_dil_nouns2 = []
word = [w for w in balaan_21_22_ux_dil_nouns if len(w) > 1]  
balaan_21_22_ux_dil_nouns2.extend(word)

# %%
balaan_21_22_ux_dil_nouns2
# Out:
# ['오늘',
#  '출발',
#  '면서',
#  '출발',
#  '협력',
#  '업체',
#  '환불',
#  '요청',
#  '반품',
#  '발란',
#  '업체',
#  '반품',
#  '반품',
#  '택배',
#  '수익',
#  '반품',
#  '사이즈',
#  '교환',
#  '비용',
#  '오늘',
#  '출발',
#  '주문',
#  '이틀',
#  '배송',
#  '준비',
#  '품절',
#  '취소',
#  '문자',
#  '해외',
#  '배송',
#  '달이',
#  '요음',
#  '반품',
#  '반품',
#  '배송비',
#  '만천원',
#  '정신',
#  '회사',
#  '판매',
#  '배송비',
#  '동봉',
#  '택배',
#  '천원',
#  '개굿',
#  '최악',
#  '생일',
#  '선물',
#  '주일',
#  '달리',
#  '홈페이지',
#  '도착',
#  '기간',
#  '기입',
#  '이해',
#  '해외',
#  '출발',
#  '고함',
#  '심지어',
#  '신발',
#  '전날',
#  '발송',
#  '당일',
#  '발송',
#  '하루',
#  '쟁일',
#  '물건',
#  '배송',
#  '예정',
#  '며칠',
#  '도착',
#  '하루',
#  '이틀',
#  '도아',
#  '고객',
#  '생각',
#  '취소',
#  '해주시',
#  '전부',
#  '해외',
#  '배송',
#  '추적',
#  '반품',
#  '처리',
#  '최악',
#  '반품',
#  '물건',
#  '주일',
#  '반품',
#  '수령',
#  '전이',
#  '표시',
#  '반품',
#  '진행',
#  '해외',
#  '배송',
#  '호주',
#  '분실',
#  '취소',
#  '고함',
#  '판매',
#  '시스템',
#  '쇼핑몰',
#  '구매',
#  '분뒤',
#  '취소',
#  '배송',
#  '채팅',
#  '물건',
#  '국내',
#  '대요',
#  '상품',
#  '당일',
#  '배송',
#  '목욜',
#  '담날',
#  '저녁',
#  '금요일',
#  '배송',
#  '준비',
#  '중도',
#  '배송',
#  '배송',
#  '배송',
#  '예정',
#  '배송',
#  '다음',
#  '약속',
#  '때문',
#  '환불',
#  '환불',
#  '그냥',
#  '광고',
#  '박아',
#  '잠깐',
#  '배송',
#  '언제',
#  '주문',
#  '제품',
#  '예송',
#  '배송',
#  '일이',
#  '아주',
#  '제품',
#  '어디',
#  '배송',
#  '조회',
#  '제대로',
#  '배송',
#  '완료',
#  '대구',
#  '인천',
#  '주문',
#  '작성자',
#  '현재',
#  '물건',
#  '물건',
#  '배송',
#  '다가',
#  '해적',
#  '진짜',
#  '별로',
#  '재고',
#  '확보',
#  '확인',
#  '물건',
#  '주문',
#  '상품',
#  '준비',
#  '문의',
#  '정도',
#  '배송',
#  '기본',
#  '고시',
#  '가격',
#  '절대',
#  '가격',
#  '해외',
#  '재고',
#  '질질',
#  '취소',
#  '최악',
#  '여기',
#  '절대',
#  '사지',
#  '반품',
#  '요청',
#  '일주일',
#  '회수',
#  '평가',
#  '보고',
#  '설치',
#  '바로',
#  '사람',
#  '배송',
#  '환불',
#  '시스템',
#  '관해',
#  '불만',
#  '개선',
#  '의지',
#  '반품',
#  '신청',
#  '경과',
#  '전화',
#  '안주시',
#  '장난',
#  '하나',
#  '구라',
#  '정도껏해',
#  '소비자보호원',
#  '신고',
#  '발란',
#  '그냥',
#  '연예인',
#  '마켓팅',
#  '그거',
#  '최악',
#  '쇼핑',
#  '진짜',
#  '위탁',
#  '판매',
#  '구입',
#  '제품',
#  '가품',
#  '의심',
#  '정도',
#  '후진',
#  '퀄리티',
#  '발란',
#  '직접',
#  '배송',
#  '가격',
#  '경쟁력',
#  '전혀',
#  '이용자',
#  '모두',
#  '반품',
#  '신청',
#  '한지',
#  '처리',
#  '먼저',
#  '연락',
#  '확인',
#  '그때',
#  '관련',
#  '부서',
#  '통해',
#  '답변',
#  '그것',
#  '반품',
#  '만원',
#  '진짜',
#  '쇼핑',
#  '무슨',
#  '럭셔리',
#  '쇼핑',
#  '적립금',
#  '손절',
#  '일단',
#  '주문',
#  '결제',
#  '문제',
#  '택배',
#  '기사',
#  '확인',
#  '무인',
#  '택배',
#  '이용',
#  '점심시간',
#  '도착',
#  '예정',
#  '그땐',
#  '경비원',
#  '전적',
#  '비번',
#  '달라',
#  '도착',
#  '진짜',
#  '그때',
#  '연락',
#  '다시',
#  '달라',
#  '끝었는데',
#  '본인',
#  '택배',
#  '기사',
#  '발란',
#  '홈페이지',
#  '확인',
#  '불가',
#  '연락',
#  '배송',
#  '완료',
#  '문자',
#  '배송',
#  '별로',
#  '제품',
#  '구매',
#  '도착',
#  '한다해',
#  '배송',
#  '당일',
#  '확인',
#  '출발',
#  '물량',
#  '배송',
#  '대기',
#  '순번',
#  '파악',
#  '거짓말',
#  '고가',
#  '제품',
#  '물량확보',
#  '일단',
#  '주문',
#  '형편',
#  '쇼핑몰',
#  '배송비',
#  '해외',
#  '직구',
#  '만원',
#  '반품',
#  '만원',
#  '상품',
#  '당일',
#  '배송',
#  '목욜',
#  '담날',
#  '저녁',
#  '금요일',
#  '배송',
#  '준비',
#  '중도',
#  '담날',
#  '주말',
#  '취소',
#  '다른',
#  '취소',
#  '신청',
#  '한지',
#  '일이',
#  '취소',
#  '확인',
#  '주말',
#  '당일',
#  '배송',
#  '주말',
#  '주로',
#  '아이쇼핑',
#  '바로',
#  '보고',
#  '물건',
#  '배송',
#  '배송',
#  '환불',
#  '백주',
#  '기스',
#  '반품',
#  '사이즈',
#  '배송',
#  '판매',
#  '자가',
#  '사이즈',
#  '구매',
#  '사이즈',
#  '배송',
#  '구매',
#  '사이즈',
#  '배송',
#  '예정',
#  '배송',
#  '메리트',
#  '배송',
#  '언제',
#  '월일',
#  '주문',
#  '제품',
#  '예송',
#  '배송',
#  '일이',
#  '월일',
#  '아주',
#  '제품',
#  '어디',
#  '배송',
#  '조회',
#  '제대로',
#  '배송',
#  '완료',
#  '대구',
#  '인천',
#  '문의',
#  '연결',
#  '주문',
#  '작성자',
#  '현재',
#  '물건',
#  '상품',
#  '준비',
#  '문의',
#  '정도',
#  '주말',
#  '당일',
#  '배송',
#  '알람',
#  '신도안',
#  '설정',
#  '찾기',
#  '진짜',
#  '정신병',
#  '어플',
#  '가기',
#  '한번',
#  '죽겠네',
#  '차라리',
#  '트렌비',
#  '낫다',
#  '비회',
#  '주문',
#  '조회',
#  '처럼',
#  '문의',
#  '가입',
#  '여자',
#  '패션',
#  '남성',
#  '패션',
#  '남성',
#  '상품',
#  '어차피',
#  '가라',
#  '말로',
#  '특가',
#  '쿠폰',
#  '장난',
#  '어플',
#  '어플',
#  '쓰레기',
#  '어플',
#  '웹페이지',
#  '로딩',
#  '속도',
#  '상품',
#  '가기',
#  '스크롤',
#  '가입',
#  '비회',
#  '결제',
#  '확인',
#  '무조건',
#  '어플',
#  '다운',
#  '대체',
#  '비회',
#  '주문',
#  '가요',
#  '광고',
#  '보고',
#  '클릭',
#  '발란',
#  '연결',
#  '광고',
#  '메인',
#  '페이지',
#  '가면',
#  '어찌',
#  '구매',
#  '하나요',
#  '모바일',
#  '광고',
#  '이름',
#  '달랑',
#  '이미지',
#  '클릭',
#  '어플',
#  '정말',
#  '광고',
#  '타고',
#  '도대체',
#  '광고',
#  '상품',
#  '연동',
#  '물건',
#  '생각',
#  '라면',
#  '기본',
#  '기능',
#  '자꾸',
#  '여성',
#  '먼저',
#  '검색',
#  '카테고리',
#  '여성',
#  '먼저',
#  '상위',
#  '버튼',
#  '다시',
#  '남성',
#  '카테고리',
#  '선택',
#  '다시',
#  '카테고리',
#  '여성',
#  '먼저',
#  '옵션',
#  '선택',
#  '불편',
#  '위시',
#  '리스트',
#  '가격',
#  '페이지',
#  '가기',
#  '크롤',
#  '이전',
#  '페이지',
#  '고정',
#  '최상',
#  '상품',
#  '크롤',
#  '탐색',
#  '에드',
#  '상품',
#  '가기',
#  '버튼',
#  '다시',
#  '꼭대기',
#  '상품',
#  '다시',
#  '구경',
#  '종료',
#  '잠시',
#  '다른',
#  '웹사이트',
#  '일보',
#  '발란',
#  '다시',
#  '초기',
#  '종료',
#  '페이지',
#  '그대로',
#  '불편',
#  '여기',
#  '구글',
#  '리뷰',
#  '최소',
#  '모바일',
#  '의류',
#  '구매',
#  '진행',
#  '사이즈',
#  '교환',
#  '요청',
#  '교환',
#  '명품',
#  '사이트',
#  '진짜',
#  '어플',
#  '거지',
#  '상세',
#  '페이',
#  '화면',
#  '확대',
#  '최악',
#  '시스템',
#  '상품',
#  '목록',
#  '상품',
#  '클릭',
#  '상세',
#  '상품',
#  '다시',
#  '목록',
#  '가기',
#  '위로',
#  '볼때',
#  '개선',
#  '안정',
#  '매우',
#  '중학생',
#  '어플',
#  '퀄리티',
#  '쓰레기',
#  '장사',
#  '제품',
#  '검색',
#  '카드',
#  '결제',
#  '요즘',
#  '불편',
#  '보기',
#  '삭제',
#  '페이지',
#  '가기',
#  '크롤',
#  '이전',
#  '페이지',
#  '고정',
#  '최상',
#  '제품',
#  '설명',
#  '비교',
#  '보험',
#  '약관',
#  '처럼',
#  '보기',
#  '깨알',
#  '글씨',
#  '표시',
#  '명품',
#  '사이트',
#  '진짜',
#  '어플',
#  '거지',
#  '제품',
#  '하나',
#  '보고',
#  '가기',
#  '처음',
#  '화면',
#  '쇼핑',
#  '래야',
#  '정말',
#  '제품',
#  '한번',
#  '보고',
#  '매번',
#  '상세',
#  '페이',
#  '화면',
#  '확대',
#  '요즘',
#  '기능',
#  '있다뇨',
#  '손가락',
#  '확대',
#  '페이',
#  '결제',
#  '아주',
#  '결제',
#  '수단',
#  '검색',
#  '기능',
#  '시스템',
#  '결제',
#  '수단',
#  '신경',
#  '카카오',
#  '페이',
#  '추가',
#  '발란',
#  '페이',
#  '원클릭',
#  '결제',
#  '랭킹',
#  '자주',
#  '선물',
#  '포장',
#  '기능',
#  '생기',
#  '조금',
#  '최악',
#  '시스템',
#  '설마',
#  '의뢰',
#  '비주',
#  '프로그래머',
#  '요청',
#  '이건',
#  '졸업',
#  '작품',
#  '수준',
#  '퀄리틴데',
#  '데이터',
#  '누수',
#  '얼마나',
#  '단가',
#  '의뢰',
#  '이상',
#  '그냥',
#  '제대로',
#  '사람',
#  '설계',
#  '수정',
#  '견적',
#  '인간',
#  '이면',
#  '관리',
#  '비용',
#  '일부러',
#  '엉망',
#  '제대로',
#  '말씀',
#  '인간',
#  '고소',
#  '계열',
#  '한가지',
#  '가격',
#  '할인',
#  '알림',
#  '디자인',
#  '개선',
#  '상품',
#  '목록',
#  '상품',
#  '클릭',
#  '상세',
#  '상품',
#  '다시',
#  '목록',
#  '가기',
#  '위로',
#  '볼때',
#  '개선',
#  '닉네임',
#  '게다가',
#  '가입',
#  '몇몇',
#  '버튼',
#  '팝업',
#  '래깅',
#  '새로고침',
#  '로그인',
#  '수락',
#  '그냥',
#  '자체',
#  '완성',
#  '기본',
#  '기능',
#  '먹통',
#  '트렌비',
#  '안정',
#  '매우',
#  '중학생',
#  '어플',
#  '퀄리티',
#  '쓰레기',
#  '장사',
#  '제품',
#  '사이트',
#  '확대',
#  '깨알',
#  '글씨',
#  '매번',
#  '싸이트',
#  '가게',
#  '추가',
#  '리뷰',
#  '제품',
#  '리뷰',
#  '난잡',
#  '신상',
#  '최저',
#  '찾기',
#  '재미',
#  '랭킹',
#  '자주']

# %%
# Counter 객체 생성
balaan_21_22_ux_dil_count = Counter(balaan_21_22_ux_dil_nouns2)

# %%
max = 10
balaan_21_22_ux_dil_10 = {}
for word, counts in balaan_21_22_ux_dil_count.most_common(max):
    balaan_21_22_ux_dil_10[word] = counts
    print(f'{word} : {counts}')
# Out:
# 배송 : 38
# 반품 : 16
# 상품 : 16
# 제품 : 13
# 주문 : 10
# 어플 : 10
# 물건 : 9
# 취소 : 8
# 다시 : 8
# 가기 : 8

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(balaan_21_22_ux_dil_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
balaan_23 = balaan[balaan['date'].str.contains('2023')]

# %%
balaan_23_app = balaan_23[balaan_23["category"]=='앱 오류']

# %%
balaan_23_sat = balaan_23[balaan_23["category"]=='만족도&기타']

# %%
balaan_23_dil = balaan_23[balaan_23["category"]=='배송']

# %%
balaan_23_ux = balaan_23[balaan_23["category"]=='UX/UI 편의성']

# %%
balaan_23_dil_ux = pd.concat([balaan_23_dil, balaan_23_ux])

# %%
balaan_23_dil_ux
# Out:
#      platform   store      date  \
# 30     balaan  google  20230912
# 176    balaan   apple  20230824
# 297    balaan  google  20230808
# 335    balaan   apple  20230801
# 336    balaan   apple  20230801
# 368    balaan  google  20230726
# 1637   balaan  google  20230427
# 1971   balaan  google  20230402
# 2136   balaan  google  20230213
# 2267   balaan  google  20230201
# 2268   balaan  google  20230201
# 210    balaan  google  20230816
# 224    balaan   apple  20230816
# 410    balaan   apple  20230721
# 411    balaan   apple  20230721
# 413    balaan   apple  20230721
# 415    balaan   apple  20230721
# 542    balaan  google  20230712
# 802    balaan  google  20230620
# 1739   balaan  google  20230415
# 1852   balaan  google  20230409
# 1853   balaan  google  20230409
# 2076   balaan  google  20230310
#
#                                                  review  rating   category  \
# 30                                    배송이 좀 늦어져서 짜증낫었는데       5         배송
# 176                                               오배송 건       1         배송
# 297                                         배송기간은 오버됐지만       5         배송
# 335                                    당일출고 내뇽은 빼셔야겠어요        3         배송
# 336                                         일반 배송보다 느려요       3         배송
# 368   가끔 기사님의 박력으로 택배상태가 안좋을때가 있는데 발란에서 잘 포장해주셔서 문제없...       5         배송
# 1637                                   뜯겨진 타브랜드스티커가 붙여진       1         배송
# 1971                             반품교환 관련해서 수수료가 너무 비싸네요       2         배송
# 2136                       믿고 구매하는 발란 배송만 쪼금 신경써서 부탁드려요       5         배송
# 2267                    한가지 바람은 오늘도착상품 서비스지역이 늘어났으면 합니다       5         배송
# 2268                                        지방민은 너무 슬퍼요       5         배송
# 210   개인쇼핑 스타일에 맞춰서 연관 상품도 자동으로 추천되고 리뷰도 다양해서 큰 도움이 됩니다       5  UX/UI 편의성
# 224   는 뭐 그렇다 치고 제발 하단네비게이션에 빽키는 왜 만든겁니까 바로 뒤로가지도 않는...       1  UX/UI 편의성
# 410    스크롤 다운하면 서치 버튼 찾으러 올라가야함 팁우측하단 위로가기 버튼은 옵션인거지...       1  UX/UI 편의성
# 411                                불필요한 카테고리 존나많아서 어지러움       1  UX/UI 편의성
# 413    웹서치 하려고 화면올리면 파란배경에 흰색으로 로고들어가있는 화면 로딩스크린때문에 ...       1  UX/UI 편의성
# 415   학생한테 디자인을 의뢰한건지 크몽에서 돈주고 맡긴건지개발팀이랑 커뮤가 안되는건지 ㅉ...       1  UX/UI 편의성
# 542                                                사용불편       3  UX/UI 편의성
# 802                                                  불편       1  UX/UI 편의성
# 1739                                      뒤로가기하면 왜 짜증나냐       3  UX/UI 편의성
# 1852  스마트폰 어플인데 스마트폰에서 상품 사진 및 설명등이 확대가 안됨 진짜 불편함 이럴...       3  UX/UI 편의성
# 1853  그리고 제품 사진이 너무 부족함 수십에서 수천만원 짜리 고가의 상품을 사진 몇장 보...       3  UX/UI 편의성
# 2076  그걸 고객인 제가 안내 사항을 인지하지 못했다고 말씀하시면 저는 판매자 발란 어느 ...       1  UX/UI 편의성
#
#       label
# 30        0
# 176       0
# 297       0
# 335       0
# 336       0
# 368       0
# 1637      0
# 1971      0
# 2136      0
# 2267      0
# 2268      0
# 210       0
# 224       0
# 410       0
# 411       0
# 413       0
# 415       0
# 542       0
# 802       0
# 1739      0
# 1852      0
# 1853      0
# 2076      0

# %%
balaan_23sur = pd.concat([balaan_23_app, balaan_23_sat])

# %%
balaan_23_dil_ux['review'] = balaan_23_dil_ux['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
balaan_23_dil_ux_nouns = []
for cmt in balaan_23_dil_ux['review']:
    balaan_23_dil_ux_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
balaan_23_dil_ux_nouns2 = []
word = [w for w in balaan_23_dil_ux_nouns if len(w) > 1]  
balaan_23_dil_ux_nouns2.extend(word)

# %%
balaan_23_dil_ux_nouns2
# Out:
# ['배송',
#  '짜증',
#  '배송',
#  '배송',
#  '기간',
#  '오버',
#  '당일',
#  '출고',
#  '내뇽',
#  '일반',
#  '배송',
#  '가끔',
#  '기사',
#  '박력',
#  '택배',
#  '상태',
#  '발란',
#  '포장',
#  '문제',
#  '브랜드',
#  '스티커',
#  '반품',
#  '교환',
#  '관련',
#  '수수료',
#  '구매',
#  '발란',
#  '배송',
#  '쪼금',
#  '신경',
#  '한가지',
#  '바람',
#  '오늘',
#  '도착',
#  '상품',
#  '서비스',
#  '지역',
#  '지방',
#  '개인',
#  '쇼핑',
#  '스타일',
#  '연관',
#  '상품',
#  '자동',
#  '추천',
#  '리뷰',
#  '도움',
#  '제발',
#  '하단',
#  '네비게이션',
#  '빽키',
#  '바로',
#  '가지',
#  '크롤',
#  '다운',
#  '서치',
#  '버튼',
#  '우측',
#  '하단',
#  '위로',
#  '가기',
#  '버튼',
#  '옵션',
#  '거지',
#  '유저',
#  '배려',
#  '디자인',
#  '심지어',
#  '화면',
#  '버튼',
#  '카테고리',
#  '존나',
#  '어지러움',
#  '서치',
#  '화면',
#  '파란',
#  '배경',
#  '흰색',
#  '로고',
#  '화면',
#  '로딩',
#  '스크린',
#  '때문',
#  '학생',
#  '디자인',
#  '의뢰',
#  '크몽',
#  '개발',
#  '커뮤',
#  '디자인',
#  '신경',
#  '사용',
#  '불편',
#  '불편',
#  '가기',
#  '스마트폰',
#  '어플',
#  '스마트폰',
#  '상품',
#  '사진',
#  '설명',
#  '확대',
#  '진짜',
#  '스마트폰',
#  '어플',
#  '모름',
#  '직원',
#  '테스트',
#  '안함',
#  '확대',
#  '제품',
#  '사진',
#  '부족함',
#  '수십',
#  '만원',
#  '고가',
#  '상품',
#  '사진',
#  '몇장',
#  '보고',
#  '결정',
#  '고객',
#  '안내',
#  '사항',
#  '인지',
#  '말씀',
#  '판매',
#  '발란',
#  '불편',
#  '얘기',
#  '개선']

# %%
# Counter 객체 생성
balaan_23_dil_ux_count = Counter(balaan_23_dil_ux_nouns2)

# %%
max = 10
balaan_23_dil_ux_10 = {}
for word, counts in balaan_23_dil_ux_count.most_common(max):
    balaan_23_dil_ux_10[word] = counts
    print(f'{word} : {counts}')
# Out:
# 배송 : 5
# 상품 : 4
# 발란 : 3
# 버튼 : 3
# 디자인 : 3
# 화면 : 3
# 불편 : 3
# 스마트폰 : 3
# 사진 : 3
# 신경 : 2

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(balaan_23_dil_ux_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()
